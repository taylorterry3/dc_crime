# %%
import pandas as pd

import seaborn as sns
import matplotlib.pylab as plt

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)


# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
incident_data = pd.read_csv(
    "../data/clean/incident_data_all.csv.gz",
    parse_dates=["date", "year", "month_year"],
    low_memory=False,
)
stop_data = pd.read_csv(
    "../data/clean/stop_data.csv.gz",
    parse_dates=["date", "year", "month_year"],
    low_memory=False,
)
arrest_data = pd.read_csv(
    "../data/clean/arrest_data.csv.gz",
    parse_dates=["date", "year", "month_year"],
    low_memory=False,
)
officer_data = pd.read_csv(
    "../data/clean/officers.csv", parse_dates=["year"], low_memory=False
)

# %%
incident_data.head().T
# Out:
#                                                        0  \
# neighborhood_cluster                           cluster 4
# offensegroup                                    property
# census_tract                                       100.0
# longitude                                     -77.058661
# end_date                           6/3/2017, 11:55:05 AM
# offense-text                                theft f/auto
# yblock                                          137666.0
# district                                             2.0
# shift                                                day
# year                                 2017-01-01 00:00:00
# ward                                                 2.0
# offensekey                         property|theft f/auto
# bid                                                  NaN
# sector                                               2D2
# psa                                                206.0
# ucr-rank                                               7
# block_group                                     000100 4
# voting_precinct                               precinct 5
# xblock                                          394912.0
# block                   2900 - 2999 block of n street nw
# start_date                         6/3/2017, 11:54:03 AM
# ccn                                              7093973
# offense                                     theft f/auto
# octo_record_id                               07093973-01
# anc                                                   2E
# report_dat                         6/3/2017, 12:54:27 PM
# method                                            others
# location              38.9068379143469,-77.0586610722644
# latitude                                       38.906838
# date                                 2017-06-03 11:54:03
# month_year                           2017-06-01 00:00:00
# year.1                                            2017.0
#
#                                                        1  \
# neighborhood_cluster                           cluster 8
# offensegroup                                    property
# census_tract                                      5802.0
# longitude                                     -77.023979
# end_date                           1/16/2020, 9:48:54 PM
# offense-text                                theft f/auto
# yblock                                          136943.0
# district                                             2.0
# shift                                            evening
# year                                 2020-01-01 00:00:00
# ward                                                 2.0
# offensekey                         property|theft f/auto
# bid                                             downtown
# sector                                               2D3
# psa                                                209.0
# ucr-rank                                               7
# block_group                                     005802 5
# voting_precinct                             precinct 129
# xblock                                          397920.0
# block                   800 - 899 block of 9th street nw
# start_date                         1/10/2020, 9:48:51 PM
# ccn                                                 5370
# offense                                     theft f/auto
# octo_record_id                               00005370-01
# anc                                                   2C
# report_dat                         1/16/2020, 9:39:05 PM
# method                                            others
# location              38.9003371408996,-77.0239787547064
# latitude                                       38.900337
# date                                 2020-01-10 21:48:51
# month_year                           2020-01-01 00:00:00
# year.1                                            2020.0
#
#                                                             2  \
# neighborhood_cluster                                cluster 7
# offensegroup                                         property
# census_tract                                           5001.0
# longitude                                          -77.030785
# end_date                               1/28/2020, 12:15:02 AM
# offense-text                                     theft f/auto
# yblock                                               138223.0
# district                                                  3.0
# shift                                                midnight
# year                                      2020-01-01 00:00:00
# ward                                                      2.0
# offensekey                              property|theft f/auto
# bid                                                       NaN
# sector                                                    3D3
# psa                                                     307.0
# ucr-rank                                                    7
# block_group                                          005001 2
# voting_precinct                                   precinct 16
# xblock                                               397330.0
# block                 1300 - 1399 block of corcoran street nw
# start_date                             1/28/2020, 12:14:58 AM
# ccn                                                     16641
# offense                                          theft f/auto
# octo_record_id                                    00016641-01
# anc                                                        2F
# report_dat                             1/28/2020, 12:14:39 AM
# method                                                 others
# location                   38.9118662323192,-77.0307853964931
# latitude                                            38.911866
# date                                      2020-01-28 00:14:58
# month_year                                2020-01-01 00:00:00
# year.1                                                 2020.0
#
#                                                        3  \
# neighborhood_cluster                           cluster 6
# offensegroup                                     violent
# census_tract                                     10700.0
# longitude                                      -77.04418
# end_date                                             NaN
# offense-text                                    homicide
# yblock                                          137533.0
# district                                             2.0
# shift                                           midnight
# year                                 2020-01-01 00:00:00
# ward                                                 2.0
# offensekey                              violent|homicide
# bid                                      golden triangle
# sector                                               2D3
# psa                                                207.0
# ucr-rank                                               1
# block_group                                     010700 1
# voting_precinct                              precinct 17
# xblock                                          396168.0
# block                   1900 - 1999 block of m street nw
# start_date                         9/23/2011, 2:40:00 AM
# ccn                                             11139598
# offense                                         homicide
# octo_record_id                               11139598-01
# anc                                                   2C
# report_dat                        8/24/2020, 12:00:00 AM
# method                                            others
# location              38.9056461773423,-77.0441795335155
# latitude                                       38.905646
# date                                 2011-09-23 02:40:00
# month_year                           2011-09-01 00:00:00
# year.1                                            2011.0
#
#                                                                  4
# neighborhood_cluster                                     cluster 6
# offensegroup                                               violent
# census_tract                                               10700.0
# longitude                                               -77.040088
# end_date                                     9/14/2013, 7:00:00 PM
# offense-text                                             sex abuse
# yblock                                                    137847.0
# district                                                       2.0
# shift                                                     midnight
# year                                           2015-01-01 00:00:00
# ward                                                           2.0
# offensekey                                       violent|sex abuse
# bid                                                            NaN
# sector                                                         2D3
# psa                                                          208.0
# ucr-rank                                                         2
# block_group                                               010700 2
# voting_precinct                                        precinct 15
# xblock                                                    396523.0
# block                 1700 - 1799 block of massachusetts avenue nw
# start_date                                  9/13/2013, 11:00:00 PM
# ccn                                                       13134420
# offense                                                  sex abuse
# octo_record_id                                         13134420-01
# anc                                                             2B
# report_dat                                  7/28/2015, 12:00:00 AM
# method                                                      others
# location                        38.9084762740098,-77.0400882912435
# latitude                                                 38.908476
# date                                           2013-09-13 23:00:00
# month_year                                     2013-09-01 00:00:00
# year.1                                                      2013.0

# %%
stop_data.head().T
# Out:
#                                                                             0  \
# ccn_anonymized              0xC57AC939B40AB78E2CE550E6A6E68592C3B016301782...
# stop_type                                                     Non-ticket Stop
# datetime                                               2019/07/22 10:14:00+00
# stop_location               3300 BLOCK OF BROTHERS PLACE SE WASHINGTON, DC...
# stop_district                                                              7D
# stop_duration_mins                                                        1.0
# stop_reason_nonticket                                     Warrant/court order
# stop_reason_harbor                                                        NaN
# stop_reason_ticket                                                        NaN
# person_search_pat_down                                                      0
# property_search_pat_down                                                    0
# person_search_consent                                                       0
# person_search_prob_cause                                                    0
# person_prot_pat_down                                                        0
# person_search_warrant                                                       0
# property_search_consent                                                     0
# property_search_prob_cause                                                  0
# property_prot_pat_down                                                      0
# property_search_warrant                                                     0
# person_search_rea_consent                                                 NaN
# person_srch_prob_cause                                                    NaN
# person_pat_down_reason                                                    NaN
# person_srch_reason_warrant                                                NaN
# prop_srch_reason_consent                                                  NaN
# prop_srch_prob_cause                                                      NaN
# prop_pat_down_reason                                                      NaN
# prop_srch_reason_warrant                                                  NaN
# property_srch_obj_consent                                                 NaN
# prop_srch_obj_prob_cause                                                  NaN
# prop_pat_down_obj                                                         NaN
# prop_srch_obj_warrant                                                     NaN
# person_srch_obj_seized_con                                                NaN
# person_srch_obj_prob_cause                                                NaN
# per_pro_pat_down_obj_seize                                                NaN
# person_srch_obj_seized_war                                                NaN
# prop_srch_obj_seize_con                                                   NaN
# prop_srch_obj_seize_cause                                                 NaN
# prop_pat_down_obj_seized                                                  NaN
# prop_search_obj_warrant                                                   NaN
# tickets_issued                                                            NaN
# warnings_issued                                                           NaN
# voided_tickets                                                            NaN
# ticket_count                                                              NaN
# warning_count                                                             NaN
# void_count                                                                NaN
# arrest_charges                                       Failure To Appear (USAO)
# gender                                                                   Male
# ethnicity                                                               Black
# age                                                                      22.0
# arrest_date                                            2019/07/22 04:00:00+00
# vehicle                                                                     0
# bicycle_pmd                                                                 0
# pedestrian                                                                  0
# harbor                                                                      0
# investigative                                                               1
# traffic_involved                                                            0
# gis_id                                                       Stop_Incidents_1
# globalid                               {B43B0EAC-0757-4733-9054-0BDEB56828EB}
# creator                                                                  JLAY
# created                                                2023/04/19 20:01:39+00
# editor                                                                   JLAY
# edited                                                 2023/04/19 20:01:39+00
# objectid                                                               492161
# date                                                2019-07-22 10:14:00+00:00
# month_year                                                2019-07-01 00:00:00
# year                                                      2019-01-01 00:00:00
#
#                                                                             1  \
# ccn_anonymized              0x481CD1BCE12C57DF02A97A91CDE56B27789502B6D329...
# stop_type                                                     Non-ticket Stop
# datetime                                               2019/07/22 11:27:00+00
# stop_location               5000 BLOCK OF HAYES STREET NE WASHINGTON, DC 2...
# stop_district                                                              6D
# stop_duration_mins                                                        1.0
# stop_reason_nonticket                                     Warrant/court order
# stop_reason_harbor                                                        NaN
# stop_reason_ticket                                                        NaN
# person_search_pat_down                                                      0
# property_search_pat_down                                                    0
# person_search_consent                                                       0
# person_search_prob_cause                                                    0
# person_prot_pat_down                                                        0
# person_search_warrant                                                       0
# property_search_consent                                                     0
# property_search_prob_cause                                                  0
# property_prot_pat_down                                                      0
# property_search_warrant                                                     0
# person_search_rea_consent                                                 NaN
# person_srch_prob_cause                                                    NaN
# person_pat_down_reason                                                    NaN
# person_srch_reason_warrant                                                NaN
# prop_srch_reason_consent                                                  NaN
# prop_srch_prob_cause                                                      NaN
# prop_pat_down_reason                                                      NaN
# prop_srch_reason_warrant                                                  NaN
# property_srch_obj_consent                                                 NaN
# prop_srch_obj_prob_cause                                                  NaN
# prop_pat_down_obj                                                         NaN
# prop_srch_obj_warrant                                                     NaN
# person_srch_obj_seized_con                                                NaN
# person_srch_obj_prob_cause                                                NaN
# per_pro_pat_down_obj_seize                                                NaN
# person_srch_obj_seized_war                                                NaN
# prop_srch_obj_seize_con                                                   NaN
# prop_srch_obj_seize_cause                                                 NaN
# prop_pat_down_obj_seized                                                  NaN
# prop_search_obj_warrant                                                   NaN
# tickets_issued                                                            NaN
# warnings_issued                                                           NaN
# voided_tickets                                                            NaN
# ticket_count                                                              NaN
# warning_count                                                             NaN
# void_count                                                                NaN
# arrest_charges                   Second Degree Cruelty To Children Grave Risk
# gender                                                                 Female
# ethnicity                                                               Black
# age                                                                      28.0
# arrest_date                                            2019/07/22 04:00:00+00
# vehicle                                                                     0
# bicycle_pmd                                                                 0
# pedestrian                                                                  0
# harbor                                                                      0
# investigative                                                               1
# traffic_involved                                                            0
# gis_id                                                       Stop_Incidents_2
# globalid                               {B40B4848-1A1C-4CC6-B707-F18719597233}
# creator                                                                  JLAY
# created                                                2023/04/19 20:01:39+00
# editor                                                                   JLAY
# edited                                                 2023/04/19 20:01:39+00
# objectid                                                               492162
# date                                                2019-07-22 11:27:00+00:00
# month_year                                                2019-07-01 00:00:00
# year                                                      2019-01-01 00:00:00
#
#                                                                             2  \
# ccn_anonymized              0x6E47B8465054475BE2B3CF8C7972F09A173691E3D5BA...
# stop_type                                                     Non-ticket Stop
# datetime                                               2019/07/22 10:50:00+00
# stop_location               3800 BLOCK OF SOUTH CAPITOL STREET SE WASHINGT...
# stop_district                                                              7D
# stop_duration_mins                                                        1.0
# stop_reason_nonticket                                     Warrant/court order
# stop_reason_harbor                                                        NaN
# stop_reason_ticket                                                        NaN
# person_search_pat_down                                                      0
# property_search_pat_down                                                    0
# person_search_consent                                                       0
# person_search_prob_cause                                                    0
# person_prot_pat_down                                                        0
# person_search_warrant                                                       0
# property_search_consent                                                     0
# property_search_prob_cause                                                  0
# property_prot_pat_down                                                      0
# property_search_warrant                                                     0
# person_search_rea_consent                                                 NaN
# person_srch_prob_cause                                                    NaN
# person_pat_down_reason                                                    NaN
# person_srch_reason_warrant                                                NaN
# prop_srch_reason_consent                                                  NaN
# prop_srch_prob_cause                                                      NaN
# prop_pat_down_reason                                                      NaN
# prop_srch_reason_warrant                                                  NaN
# property_srch_obj_consent                                                 NaN
# prop_srch_obj_prob_cause                                                  NaN
# prop_pat_down_obj                                                         NaN
# prop_srch_obj_warrant                                                     NaN
# person_srch_obj_seized_con                                                NaN
# person_srch_obj_prob_cause                                                NaN
# per_pro_pat_down_obj_seize                                                NaN
# person_srch_obj_seized_war                                                NaN
# prop_srch_obj_seize_con                                                   NaN
# prop_srch_obj_seize_cause                                                 NaN
# prop_pat_down_obj_seized                                                  NaN
# prop_search_obj_warrant                                                   NaN
# tickets_issued                                                            NaN
# warnings_issued                                                           NaN
# voided_tickets                                                            NaN
# ticket_count                                                              NaN
# warning_count                                                             NaN
# void_count                                                                NaN
# arrest_charges                                  Probation Violation (Warrant)
# gender                                                                 Female
# ethnicity                                                               Black
# age                                                                      33.0
# arrest_date                                            2019/07/22 04:00:00+00
# vehicle                                                                     0
# bicycle_pmd                                                                 0
# pedestrian                                                                  0
# harbor                                                                      0
# investigative                                                               1
# traffic_involved                                                            0
# gis_id                                                       Stop_Incidents_3
# globalid                               {C8B860DB-79A3-44A2-BB28-C38620F838EC}
# creator                                                                  JLAY
# created                                                2023/04/19 20:01:39+00
# editor                                                                   JLAY
# edited                                                 2023/04/19 20:01:39+00
# objectid                                                               492163
# date                                                2019-07-22 10:50:00+00:00
# month_year                                                2019-07-01 00:00:00
# year                                                      2019-01-01 00:00:00
#
#                                                                             3  \
# ccn_anonymized              0x69889283B23CF88C1600DA5BD333CA5CD7263F58E0EA...
# stop_type                                                     Non-ticket Stop
# datetime                                               2019/07/22 10:39:00+00
# stop_location               3800 BLOCK OF SOUTH CAPITOL STREET SE WASHINGT...
# stop_district                                                              7D
# stop_duration_mins                                                        1.0
# stop_reason_nonticket                                     Warrant/court order
# stop_reason_harbor                                                        NaN
# stop_reason_ticket                                                        NaN
# person_search_pat_down                                                      0
# property_search_pat_down                                                    0
# person_search_consent                                                       0
# person_search_prob_cause                                                    0
# person_prot_pat_down                                                        0
# person_search_warrant                                                       0
# property_search_consent                                                     0
# property_search_prob_cause                                                  0
# property_prot_pat_down                                                      0
# property_search_warrant                                                     0
# person_search_rea_consent                                                 NaN
# person_srch_prob_cause                                                    NaN
# person_pat_down_reason                                                    NaN
# person_srch_reason_warrant                                                NaN
# prop_srch_reason_consent                                                  NaN
# prop_srch_prob_cause                                                      NaN
# prop_pat_down_reason                                                      NaN
# prop_srch_reason_warrant                                                  NaN
# property_srch_obj_consent                                                 NaN
# prop_srch_obj_prob_cause                                                  NaN
# prop_pat_down_obj                                                         NaN
# prop_srch_obj_warrant                                                     NaN
# person_srch_obj_seized_con                                                NaN
# person_srch_obj_prob_cause                                                NaN
# per_pro_pat_down_obj_seize                                                NaN
# person_srch_obj_seized_war                                                NaN
# prop_srch_obj_seize_con                                                   NaN
# prop_srch_obj_seize_cause                                                 NaN
# prop_pat_down_obj_seized                                                  NaN
# prop_search_obj_warrant                                                   NaN
# tickets_issued                                                            NaN
# warnings_issued                                                           NaN
# voided_tickets                                                            NaN
# ticket_count                                                              NaN
# warning_count                                                             NaN
# void_count                                                                NaN
# arrest_charges                                     Parole Violation (Warrant)
# gender                                                                   Male
# ethnicity                                                               Black
# age                                                                      55.0
# arrest_date                                            2019/07/22 04:00:00+00
# vehicle                                                                     0
# bicycle_pmd                                                                 0
# pedestrian                                                                  0
# harbor                                                                      0
# investigative                                                               1
# traffic_involved                                                            0
# gis_id                                                       Stop_Incidents_4
# globalid                               {441D451A-4800-474F-8B43-5FE0537D7B0E}
# creator                                                                  JLAY
# created                                                2023/04/19 20:01:39+00
# editor                                                                   JLAY
# edited                                                 2023/04/19 20:01:39+00
# objectid                                                               492164
# date                                                2019-07-22 10:39:00+00:00
# month_year                                                2019-07-01 00:00:00
# year                                                      2019-01-01 00:00:00
#
#                                                                             4
# ccn_anonymized              0xA630FAD3F2DD45C542E07032FE9753AE79DCEE019581...
# stop_type                                                     Non-ticket Stop
# datetime                                               2019/07/22 11:57:00+00
# stop_location               100 BLOCK OF RIDGE ROAD SE WASHINGTON, DC 2001...
# stop_district                                                              6D
# stop_duration_mins                                                        3.0
# stop_reason_nonticket                                     Warrant/court order
# stop_reason_harbor                                                        NaN
# stop_reason_ticket                                                        NaN
# person_search_pat_down                                                      1
# property_search_pat_down                                                    0
# person_search_consent                                                       0
# person_search_prob_cause                                                    0
# person_prot_pat_down                                                        0
# person_search_warrant                                                       1
# property_search_consent                                                     0
# property_search_prob_cause                                                  0
# property_prot_pat_down                                                      0
# property_search_warrant                                                     0
# person_search_rea_consent                                                 NaN
# person_srch_prob_cause                                                    NaN
# person_pat_down_reason                                                    NaN
# person_srch_reason_warrant                    Warrant (warrant search only) ;
# prop_srch_reason_consent                                                  NaN
# prop_srch_prob_cause                                                      NaN
# prop_pat_down_reason                                                      NaN
# prop_srch_reason_warrant                                                  NaN
# property_srch_obj_consent                                                 NaN
# prop_srch_obj_prob_cause                                                  NaN
# prop_pat_down_obj                                                         NaN
# prop_srch_obj_warrant                                                     NaN
# person_srch_obj_seized_con                                                NaN
# person_srch_obj_prob_cause                                                NaN
# per_pro_pat_down_obj_seize                                                NaN
# person_srch_obj_seized_war                                             None ;
# prop_srch_obj_seize_con                                                   NaN
# prop_srch_obj_seize_cause                                                 NaN
# prop_pat_down_obj_seized                                                  NaN
# prop_search_obj_warrant                                                   NaN
# tickets_issued                                                            NaN
# warnings_issued                                                           NaN
# voided_tickets                                                            NaN
# ticket_count                                                              NaN
# warning_count                                                             NaN
# void_count                                                                NaN
# arrest_charges                                     Parole Violation (Warrant)
# gender                                                                   Male
# ethnicity                                                            Hispanic
# age                                                                      29.0
# arrest_date                                            2019/07/22 04:00:00+00
# vehicle                                                                     0
# bicycle_pmd                                                                 0
# pedestrian                                                                  0
# harbor                                                                      0
# investigative                                                               1
# traffic_involved                                                            0
# gis_id                                                       Stop_Incidents_5
# globalid                               {ABB86702-C077-46C2-9264-09EADA4A65B3}
# creator                                                                  JLAY
# created                                                2023/04/19 20:01:39+00
# editor                                                                   JLAY
# edited                                                 2023/04/19 20:01:39+00
# objectid                                                               492165
# date                                                2019-07-22 11:57:00+00:00
# month_year                                                2019-07-01 00:00:00
# year                                                      2019-01-01 00:00:00

# %%
arrest_data.head().T
# Out:
#                                                                     0  \
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/11/14 05:00:00+00
# hour                                                                6
# ccn                 45bb932cb42f1bba872a8dfcfb2428a10d6fe0598a63f2...
# arrest_number       1057043c3187ebc5c85920edbb441300e1446d3764e70f...
# age                                                                37
# defendant_psa                                            Out of State
# defendant_district                                       Out of State
# race                                                            WHITE
# ethnicity                                                NOT HISPANIC
# sex                                                              MALE
# category                                                    Sex Abuse
# description                      Second Degree Sex Abuse- Incompetent
# arrest_psa                                                      102.0
# arrest_district                                                    1D
# arrest_blockx                                                398600.0
# arrest_blocky                                                136300.0
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       NaN
# offense_district                                                  NaN
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_1
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {80CA3650-32C9-42C6-8412-9250D0E433BF}
# objectid                                                            1
# date                                        2013-11-14 05:00:00+00:00
# month_year                                        2013-11-01 00:00:00
# year.1                                                           2013
#
#                                                                     1  \
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/11/20 05:00:00+00
# hour                                                               15
# ccn                 d558ea651a7b32e88571a453ccdf39376b2ec9dfb11f3c...
# arrest_number       ad3f22534b1e2c409d66328bb4ac3904e9bacc768c6091...
# age                                                                39
# defendant_psa                                                     602
# defendant_district                                                 6D
# race                                                            BLACK
# ethnicity                                                         NaN
# sex                                                              MALE
# category                                                     Homicide
# description                                                  Murder I
# arrest_psa                                                      602.0
# arrest_district                                                    6D
# arrest_blockx                                                405900.0
# arrest_blocky                                                137300.0
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       602
# offense_district                                                   6D
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_2
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {F1B2E42E-38B5-49D6-8A60-BF8CF0690A12}
# objectid                                                            2
# date                                        2013-11-20 05:00:00+00:00
# month_year                                        2013-11-01 00:00:00
# year.1                                                           2013
#
#                                                                     2  \
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/12/03 05:00:00+00
# hour                                                                0
# ccn                 85451f87475b042563ddebc20b89b7258f07bca9b55b77...
# arrest_number       a723e9f1d0b44a6e0cef81994b8e7d3d3da55270e6f871...
# age                                                                40
# defendant_psa                                            Out of State
# defendant_district                                       Out of State
# race                                                            BLACK
# ethnicity                                                         NaN
# sex                                                              MALE
# category                                                 Prostitution
# description                                    Solicting Prostitution
# arrest_psa                                                      103.0
# arrest_district                                                    1D
# arrest_blockx                                                399200.0
# arrest_blocky                                                137200.0
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       NaN
# offense_district                                                  NaN
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_3
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {7F8BA37F-51F5-437F-A8F4-4B755385797B}
# objectid                                                            3
# date                                        2013-12-03 05:00:00+00:00
# month_year                                        2013-12-01 00:00:00
# year.1                                                           2013
#
#                                                                     3  \
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/12/05 05:00:00+00
# hour                                                               21
# ccn                 3498c726acd19b8fc48c50a86c4e21e5823c41722cb779...
# arrest_number       1a94d5a92f8538d3252aa65690ab70fac1a67646eb22ee...
# age                                                                65
# defendant_psa                                                     502
# defendant_district                                                 5D
# race                                                            BLACK
# ethnicity                                                         NaN
# sex                                                              MALE
# category                                                      rcotics
# description                                          Ucsa Pwid Heroin
# arrest_psa                                                      102.0
# arrest_district                                                    1D
# arrest_blockx                                                398400.0
# arrest_blocky                                                136900.0
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       NaN
# offense_district                                                  NaN
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_4
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {70B94138-C9F4-4CFF-9A72-12B071F3A78C}
# objectid                                                            4
# date                                        2013-12-05 05:00:00+00:00
# month_year                                        2013-12-01 00:00:00
# year.1                                                           2013
#
#                                                                     4
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/12/09 05:00:00+00
# hour                                                               23
# ccn                 88e342ab716f545b67c467914d6999d514ec6ea34d5c2e...
# arrest_number       5a0e432aaa38e011a7b8aa29de617d4e635acab29b3db5...
# age                                                                31
# defendant_psa                                                     702
# defendant_district                                                 7D
# race                                                            BLACK
# ethnicity                                                NOT HISPANIC
# sex                                                              MALE
# category                                           Traffic Violations
# description                                                 No Permit
# arrest_psa                                                      204.0
# arrest_district                                                    2D
# arrest_blockx                                                     NaN
# arrest_blocky                                                     NaN
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       NaN
# offense_district                                                  NaN
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_5
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {2DCB5E7E-311F-48B8-A36B-BF1D6C2890F5}
# objectid                                                            5
# date                                        2013-12-09 05:00:00+00:00
# month_year                                        2013-12-01 00:00:00
# year.1                                                           2013

# %%
officer_data
# Out:
#          year  officers
# 0  1999-01-01      3466
# 1  2000-01-01      3628
# 2  2001-01-01      3616
# 3  2002-01-01      3637
# 4  2003-01-01      3664
# 5  2004-01-01      3800
# 6  2005-01-01      3801
# 7  2006-01-01      3800
# 8  2007-01-01      3910
# 9  2008-01-01      4051
# 10 2009-01-01      4032
# 11 2010-01-01      3961
# 12 2011-01-01      3801
# 13 2012-01-01      3899
# 14 2013-01-01      4010
# 15 2014-01-01      3972
# 16 2015-01-01      3837
# 17 2016-01-01      3737
# 18 2017-01-01      3821
# 19 2018-01-01      3855
# 20 2019-01-01      3810
# 21 2020-01-01      3799
# 22 2021-01-01      3580
# 23 2022-01-01      3460
# 24 2023-01-01      3386

# %% [markdown]
# ## Data Ranges

# %%
[(d.year.min(), d.year.max()) for d in [incident_data, stop_data, arrest_data]]
# Out:
# [(Timestamp('2015-01-01 00:00:00'), Timestamp('2023-01-01 00:00:00')),
#  (Timestamp('2019-01-01 00:00:00'), Timestamp('2022-01-01 00:00:00')),
#  (Timestamp('2013-01-01 00:00:00'), Timestamp('2022-01-01 00:00:00'))]

# %%
dir(incident_data)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pandas_priority__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_accum_func',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_align_for_op',
#  '_align_frame',
#  '_align_series',
#  '_append',
#  '_arith_method',
#  '_arith_method_with_reindex',
#  '_as_manager',
#  '_attrs',
#  '_box_col_values',
#  '_can_fast_transpose',
#  '_check_inplace_and_allows_duplicate_labels',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_cmp_method',
#  '_combine_frame',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_result',
#  '_constructor',
#  '_constructor_from_mgr',
#  '_constructor_sliced',
#  '_constructor_sliced_from_mgr',
#  '_create_data_for_split_and_tight_to_dict',
#  '_data',
#  '_deprecate_downcast',
#  '_dir_additions',
#  '_dir_deletions',
#  '_dispatch_frame_op',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_flags',
#  '_flex_arith_method',
#  '_flex_cmp_method',
#  '_from_arrays',
#  '_from_mgr',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cleaned_column_resolvers',
#  '_get_column_array',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_getitem_nocopy',
#  '_getitem_slice',
#  '_gotitem',
#  '_hidden_attrs',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_inplace_method',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_copy',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_iset_item',
#  '_iset_item_mgr',
#  '_iset_not_inplace',
#  '_item_cache',
#  '_iter_column_arrays',
#  '_ixs',
#  '_logical_func',
#  '_logical_method',
#  '_maybe_align_series_as_frame',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_mgr',
#  '_min_count_stat_function',
#  '_needs_reindex_multi',
#  '_pad_or_backfill',
#  '_protect_consolidate',
#  '_reduce',
#  '_reduce_axis1',
#  '_reindex_axes',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_rename',
#  '_replace_columnwise',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_series',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_axis_nocheck',
#  '_set_is_copy',
#  '_set_item',
#  '_set_item_frame_value',
#  '_set_item_mgr',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_shift_with_freq',
#  '_should_reindex_frame_op',
#  '_slice',
#  '_sliced_from_mgr',
#  '_stat_function',
#  '_stat_function_ddof',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_to_latex_via_styler',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'anc',
#  'any',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'axes',
#  'backfill',
#  'between_time',
#  'bfill',
#  'bid',
#  'block',
#  'block_group',
#  'bool',
#  'boxplot',
#  'ccn',
#  'census_tract',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'date',
#  'describe',
#  'diff',
#  'district',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'end_date',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'from_dict',
#  'from_records',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isetitem',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'latitude',
#  'le',
#  'loc',
#  'location',
#  'longitude',
#  'lt',
#  'map',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'method',
#  'min',
#  'mod',
#  'mode',
#  'month_year',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'neighborhood_cluster',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'octo_record_id',
#  'offense',
#  'offensegroup',
#  'offensekey',
#  'pad',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'psa',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'report_dat',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'sector',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'start_date',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_orc',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'to_xml',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'voting_precinct',
#  'ward',
#  'where',
#  'xblock',
#  'xs',
#  'yblock',
#  'year']

# %% [markdown]
# ## MPD Staffing

# %%
sns.set(rc={"figure.figsize": (14, 6)})
sns.barplot(
    data=officer_data,
    x=officer_data.year.dt.strftime("%Y"), # hack
    y="officers",
    color="navy",
    width=0.4,
).set(title="MPD Historical Sworn Staffing")
# Out:
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# [Text(0.5, 1.0, 'MPD Historical Sworn Staffing')]

# %% [markdown]
# ## Scale Incident Data to 2019

# %%
incidents_by_month = (
    incident_data.groupby(["month_year", "offense"])
    .octo_record_id.count()
    .reset_index()
)

# %%
# fix this if older data is added
incidents_by_month = incidents_by_month[
    (incidents_by_month.month_year > "2015-12")
    & (incidents_by_month.month_year < "2023-03")
]

# very few arsons, just dropping this
incidents_by_month = incidents_by_month[incidents_by_month.offense != "arson"]

# %%
incidents_by_month.columns = ["Date", "Offense", "Count"]

# %%
incidents_2019_monthly_averages = (
    incidents_by_month[incidents_by_month.Date.dt.strftime("%Y") == "2019"] # wrong way to do this
    .groupby("Offense")
    .agg({"Count": "mean"})
    .to_dict()
)[
    "Count"
]  # hack to get rid of nested dict

incidents_by_month["Normalized Count"] = incidents_by_month.apply(
    lambda x: x["Count"] / incidents_2019_monthly_averages[x["Offense"]], axis=1
)

# %%
# sanity check
incidents_2019_monthly_averages
# Out:
# {'assault w/dangerous weapon': 131.16666666666666,
#  'burglary': 105.83333333333333,
#  'homicide': 13.833333333333334,
#  'motor vehicle theft': 182.83333333333334,
#  'robbery': 186.41666666666666,
#  'sex abuse': 16.333333333333332,
#  'theft f/auto': 893.9166666666666,
#  'theft/other': 1291.4166666666667}

# %% [markdown]
# ## Incidents by Type

# %%
sns.set(rc={"figure.figsize": (14, 6)})
g = sns.lineplot(
    data=incidents_by_month[
        incidents_by_month.Offense.isin(
            ["assault w/dangerous weapon", "homicide", "robbery", "sex abuse"]
        )
    ],
    x="Date",
    y="Count",
    hue="Offense"
)
# Out:
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Too busy and needs the x fixed
sns.set(rc={"figure.figsize": (14, 6)})
g = sns.lineplot(data=incidents_by_month, x="Date", y="Normalized Count", hue="Offense")
# Out:
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Break out invariant reporting and other types of crimes
incidents_by_month["Crime Type"] = [
    i if i in ["homicide", "motor vehicle theft"] else "other crimes"
    for i in incidents_by_month.Offense
]

incidents_by_month.sort_values("Crime Type", inplace=True) # hack for graph ordering

# %%
# labels still bad but it makes the point
sns.set(rc={"figure.figsize": (14, 6)})
g = sns.lineplot(data=incidents_by_month, x="Date", y="Normalized Count", hue="Crime Type", errorbar=None)
g.axhline(y=1, ls="--", c="green")
g.set(title="Crime Incidents per Month, Homicide and Car Theft vs. Others (normalized to 2019)")
# Out:
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# [Text(0.5, 1.0, 'Crime Incidents per Month, Homicide and Car Theft vs. Others (normalized to 2019)')]

# %%
# facet grid instead
sns.set(rc={"figure.figsize": (14, 6)})
g = sns.FacetGrid(data=incidents_by_month, row="Crime Type", height=2, aspect=6)
g.set(
    xlim=(incidents_by_month.Date.min(), incidents_by_month.Date.max())
)  # something is broken, this is a hack
g.set(ylim=(0.4, 2.4))
g.map(plt.axhline, y=1, ls="--", c="orange")
g.map(plt.axvline, x=pd.to_datetime("2020-04-01"), ls="--", c="green")
g.map_dataframe(sns.lineplot, x="Date", y="Normalized Count", errorbar=None)
g.add_legend()
# Out:
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# facet grid of all offense types
sns.set(rc={"figure.figsize": (14, 6)})
g = sns.FacetGrid(data=incidents_by_month, row="Offense", height=2, aspect=6)
g.set(xlim=(incidents_by_month.Date.min(), incidents_by_month.Date.max())) # something is broken, this is a hack
g.set(ylim=(0.4, 2.4))
g.map(plt.axhline, y=1, ls="--", c="orange")
g.map(plt.axvline, x=pd.to_datetime("2020-04-01"), ls="--", c="green")
g.map_dataframe(sns.lineplot, x="Date", y="Normalized Count")
g.add_legend()
# Out:
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/tterry/projects/dc-public-data/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Stop Data

# %%
# Really annoying formatting here
stop_data.stop_reason_nonticket.value_counts().head()
# Out:
# stop_reason_nonticket
# Call for service               38315
# Traffic violation              11551
# Warrant/court order             9507
# Individual<U+0092>s actions     6794
# BOLO/Lookout                    6502
# Name: count, dtype: int64

# %%
stop_data.stop_reason_ticket.value_counts().head()
# Out:
# stop_reason_ticket
# Observed moving violation       127917
# Observed equipment violation     15292
# Calls for service                10021
# Response to Crash                 8793
# BOLO/Lookout                       322
# Name: count, dtype: int64

# %%
g = (
    stop_data[
    (stop_data.stop_reason_nonticket == "Call for service")
    | (stop_data.stop_reason_ticket == "Calls for service")
].groupby("month_year").objectid.count()[1:-1].plot()
)  # [1:-1] to remove incomplete months

g.set(title="MPD Stops Recorded as Call for Service per Month", xlabel=None, ylim=(0, None))
# Out:
# [Text(0.5, 1.0, 'MPD Stops Recorded as Call for Service per Month'),
#  Text(0.5, 0, ''),
#  (0.0, 1655.8)]

# %%
g = (
    stop_data.groupby("month_year").objectid.count()[1:-1].plot()
)  # [1:-1] to remove incomplete months

g.set(title="MPD Stops per Month", xlabel=None, ylim=(0, None))
# Out:
# [Text(0.5, 1.0, 'MPD Stops per Month'), Text(0.5, 0, ''), (0.0, 14080.4)]

# %%
g = (
    stop_data[stop_data.stop_reason_ticket == "Observed equipment violation"]
    .groupby("month_year")
    .objectid.count()[1:]
    .plot()
)  # [1:] to remove an incomplete month
g.set(
    title="MPD Observed Equipment Violation Stops per Month",
    xlabel=None,
    ylim=(0, None),
)
# Out:
# [Text(0.5, 1.0, 'MPD Observed Equipment Violation Stops per Month'),
#  Text(0.5, 0, ''),
#  (0.0, 1209.25)]

# %%
g = (
    stop_data[stop_data.stop_reason_ticket == "Observed moving violation"]
    .groupby("month_year")
    .objectid.count()[1:-1]
    .plot()
)  # [1:-1] to remove incomplete months
g.set(
    title="MPD Observed Moving Violation Stops per Month",
    xlabel=None,
    ylim=(0, None),
)
# Out:
# [Text(0.5, 1.0, 'MPD Observed Moving Violation Stops per Month'),
#  Text(0.5, 0, ''),
#  (0.0, 7690.6)]

# %% [markdown]
# ## Arrest Data

# %%
sns.set(rc={"figure.figsize": (14, 6)})
g = arrest_data.groupby("month_year").objectid.count().plot()
g.set(
    title="MPD Monthly Arrests",
    xlabel=None,
    ylim=(0, None),
)
# Out:
# [Text(0.5, 1.0, 'MPD Monthly Arrests'), Text(0.5, 0, ''), (0.0, 3313.45)]
