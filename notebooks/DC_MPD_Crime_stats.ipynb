# %%
import pandas as pd

import seaborn as sns
import matplotlib.pylab as plt

import warnings
warnings.filterwarnings('ignore')

pd.set_option("display.max_rows", 999)
pd.set_option("display.max_columns", 999)


# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
incident_data = pd.read_csv(
    "../data/clean/incident_data.csv.gz",
    parse_dates=["date", "year", "month_year"],
    low_memory=False,
)
stop_data = pd.read_csv(
    "../data/clean/stop_data.csv.gz",
    parse_dates=["date", "year", "month_year"],
    low_memory=False,
)
arrest_data = pd.read_csv(
    "../data/clean/arrest_data.csv.gz",
    parse_dates=["date", "year", "month_year"],
    low_memory=False,
)
officer_data = pd.read_csv(
    "../data/clean/officers.csv", parse_dates=["year"], low_memory=False
)

# %%
incident_data.head().T
# Out:
#                                                        0  \
# x                                             -76.963243
# y                                              38.925035
# ccn                                             21029645
# report_dat                        2021/03/08 14:06:13+00
# shift                                                DAY
# method                                            OTHERS
# offense                                     THEFT F/AUTO
# block                 3100 - 3199 BLOCK OF APPLE ROAD NE
# xblock                                         403187.48
# yblock                                         139684.18
# ward                                                 5.0
# anc                                                   5C
# district                                             5.0
# psa                                                503.0
# neighborhood_cluster                          Cluster 24
# block_group                                     009000 1
# census_tract                                      9000.0
# voting_precinct                             Precinct 139
# latitude                                       38.925027
# longitude                                     -76.963241
# bid                                                  NaN
# start_date                        2021/03/08 00:00:23+00
# end_date                          2021/03/08 13:00:28+00
# objectid                                       296954189
# octo_record_id                                       NaN
# date                           2021-03-08 00:00:23+00:00
# month_year                           2021-03-01 00:00:00
# year                                 2021-01-01 00:00:00
#
#                                                           1  \
# x                                                -77.073113
# y                                                 38.937336
# ccn                                                21029649
# report_dat                           2021/03/08 14:27:38+00
# shift                                                   DAY
# method                                               OTHERS
# offense                                            BURGLARY
# block                 3700 - 3799 BLOCK OF PORTER STREET NW
# xblock                                            393661.44
# yblock                                            141051.53
# ward                                                    3.0
# anc                                                      3A
# district                                                2.0
# psa                                                   203.0
# neighborhood_cluster                             Cluster 15
# block_group                                        000600 4
# census_tract                                          600.0
# voting_precinct                                 Precinct 29
# latitude                                          38.937328
# longitude                                         -77.07311
# bid                                                     NaN
# start_date                           2021/03/08 14:19:23+00
# end_date                             2021/03/08 14:20:37+00
# objectid                                          296954190
# octo_record_id                                          NaN
# date                              2021-03-08 14:19:23+00:00
# month_year                              2021-03-01 00:00:00
# year                                    2021-01-01 00:00:00
#
#                                                             2  \
# x                                                  -76.971909
# y                                                    38.84779
# ccn                                                  21029667
# report_dat                             2021/03/08 15:54:20+00
# shift                                                     DAY
# method                                                 OTHERS
# offense                                           THEFT/OTHER
# block                 2200 - 2299 BLOCK OF SAVANNAH STREET SE
# xblock                                           402438.66448
# yblock                                          131109.085399
# ward                                                      8.0
# anc                                                        8E
# district                                                  7.0
# psa                                                     704.0
# neighborhood_cluster                               Cluster 38
# block_group                                          007409 2
# census_tract                                           7409.0
# voting_precinct                                  Precinct 116
# latitude                                            38.847782
# longitude                                          -76.971907
# bid                                                       NaN
# start_date                             2021/03/08 14:54:31+00
# end_date                               2021/03/08 15:22:56+00
# objectid                                            296954191
# octo_record_id                                            NaN
# date                                2021-03-08 14:54:31+00:00
# month_year                                2021-03-01 00:00:00
# year                                      2021-01-01 00:00:00
#
#                                                                       3  \
# x                                                            -76.991735
# y                                                             38.863048
# ccn                                                            21029668
# report_dat                                       2021/03/08 15:46:58+00
# shift                                                               DAY
# method                                                           OTHERS
# offense                                                    THEFT F/AUTO
# block                 2300 - 2399 BLOCK OF MARTIN LUTHER KING JR AVE...
# xblock                                                        400717.53
# yblock                                                        132802.55
# ward                                                                8.0
# anc                                                                  8A
# district                                                            7.0
# psa                                                               703.0
# neighborhood_cluster                                         Cluster 37
# block_group                                                    007401 1
# census_tract                                                     7401.0
# voting_precinct                                            Precinct 119
# latitude                                                      38.863041
# longitude                                                    -76.991732
# bid                                                           ANACOSTIA
# start_date                                       2021/03/08 01:00:17+00
# end_date                                         2021/03/08 15:10:23+00
# objectid                                                      296954192
# octo_record_id                                                      NaN
# date                                          2021-03-08 01:00:17+00:00
# month_year                                          2021-03-01 00:00:00
# year                                                2021-01-01 00:00:00
#
#                                                         4
# x                                              -77.036482
# y                                                38.92793
# ccn                                              21029675
# report_dat                         2021/03/08 16:13:18+00
# shift                                                 DAY
# method                                             OTHERS
# offense                                          BURGLARY
# block                 3032 - 3099 BLOCK OF 16TH STREET NW
# xblock                                          396836.88
# yblock                                          140005.49
# ward                                                  1.0
# anc                                                    1D
# district                                              3.0
# psa                                                 302.0
# neighborhood_cluster                            Cluster 2
# block_group                                      002702 4
# census_tract                                       2702.0
# voting_precinct                               Precinct 39
# latitude                                        38.927922
# longitude                                      -77.036479
# bid                                                   NaN
# start_date                         2021/03/08 09:13:22+00
# end_date                           2021/03/08 09:55:38+00
# objectid                                        296954193
# octo_record_id                                        NaN
# date                            2021-03-08 09:13:22+00:00
# month_year                            2021-03-01 00:00:00
# year                                  2021-01-01 00:00:00

# %%
stop_data.head().T
# Out:
#                                                                             0  \
# stop_reason_nonticket                                     Warrant/court order
# ethnicity                                                               Black
# stop_reason_ticket                                                        NaN
# stop_type                                                     Non-ticket Stop
# age                                                                      22.0
# pedestrian                                                                  0
# prop_srch_reason_consent                                                  NaN
# prop_srch_reason_warrant                                                  NaN
# prop_pat_down_obj_seized                                                  NaN
# prop_pat_down_obj                                                         NaN
# harbor                                                                      0
# gis_id                                                       Stop_Incidents_1
# objectid                                                               492161
# stop_district                                                              7D
# stop_reason_harbor                                                        NaN
# property_prot_pat_down                                                      0
# person_search_rea_consent                                                 NaN
# warning_count                                                             NaN
# prop_srch_obj_warrant                                                     NaN
# prop_pat_down_reason                                                      NaN
# person_srch_obj_prob_cause                                                NaN
# prop_srch_obj_seize_cause                                                 NaN
# person_search_pat_down                                                      0
# person_srch_reason_warrant                                                NaN
# gender                                                                   Male
# prop_search_obj_warrant                                                   NaN
# voided_tickets                                                            NaN
# arrest_charges                                       Failure To Appear (USAO)
# globalid                               {B43B0EAC-0757-4733-9054-0BDEB56828EB}
# property_srch_obj_consent                                                 NaN
# per_pro_pat_down_obj_seize                                                NaN
# stop_duration_mins                                                        1.0
# warnings_issued                                                           NaN
# vehicle                                                                     0
# person_search_warrant                                                       0
# person_srch_obj_seized_war                                                NaN
# prop_srch_prob_cause                                                      NaN
# prop_srch_obj_seize_con                                                   NaN
# arrest_date                                            2019/07/22 04:00:00+00
# prop_srch_obj_prob_cause                                                  NaN
# investigative                                                               1
# datetime                                               2019/07/22 10:14:00+00
# person_srch_obj_seized_con                                                NaN
# ccn_anonymized              0xC57AC939B40AB78E2CE550E6A6E68592C3B016301782...
# property_search_prob_cause                                                  0
# person_pat_down_reason                                                    NaN
# traffic_involved                                                            0
# person_prot_pat_down                                                        0
# tickets_issued                                                            NaN
# property_search_warrant                                                     0
# void_count                                                                NaN
# bicycle_pmd                                                                 0
# property_search_pat_down                                                    0
# property_search_consent                                                     0
# person_srch_prob_cause                                                    NaN
# person_search_prob_cause                                                    0
# ticket_count                                                              NaN
# person_search_consent                                                       0
# date                                                2019-07-22 10:14:00+00:00
# month_year                                                2019-07-01 00:00:00
# year                                                      2019-01-01 00:00:00
#
#                                                                             1  \
# stop_reason_nonticket                                     Warrant/court order
# ethnicity                                                               Black
# stop_reason_ticket                                                        NaN
# stop_type                                                     Non-ticket Stop
# age                                                                      28.0
# pedestrian                                                                  0
# prop_srch_reason_consent                                                  NaN
# prop_srch_reason_warrant                                                  NaN
# prop_pat_down_obj_seized                                                  NaN
# prop_pat_down_obj                                                         NaN
# harbor                                                                      0
# gis_id                                                       Stop_Incidents_2
# objectid                                                               492162
# stop_district                                                              6D
# stop_reason_harbor                                                        NaN
# property_prot_pat_down                                                      0
# person_search_rea_consent                                                 NaN
# warning_count                                                             NaN
# prop_srch_obj_warrant                                                     NaN
# prop_pat_down_reason                                                      NaN
# person_srch_obj_prob_cause                                                NaN
# prop_srch_obj_seize_cause                                                 NaN
# person_search_pat_down                                                      0
# person_srch_reason_warrant                                                NaN
# gender                                                                 Female
# prop_search_obj_warrant                                                   NaN
# voided_tickets                                                            NaN
# arrest_charges                   Second Degree Cruelty To Children Grave Risk
# globalid                               {B40B4848-1A1C-4CC6-B707-F18719597233}
# property_srch_obj_consent                                                 NaN
# per_pro_pat_down_obj_seize                                                NaN
# stop_duration_mins                                                        1.0
# warnings_issued                                                           NaN
# vehicle                                                                     0
# person_search_warrant                                                       0
# person_srch_obj_seized_war                                                NaN
# prop_srch_prob_cause                                                      NaN
# prop_srch_obj_seize_con                                                   NaN
# arrest_date                                            2019/07/22 04:00:00+00
# prop_srch_obj_prob_cause                                                  NaN
# investigative                                                               1
# datetime                                               2019/07/22 11:27:00+00
# person_srch_obj_seized_con                                                NaN
# ccn_anonymized              0x481CD1BCE12C57DF02A97A91CDE56B27789502B6D329...
# property_search_prob_cause                                                  0
# person_pat_down_reason                                                    NaN
# traffic_involved                                                            0
# person_prot_pat_down                                                        0
# tickets_issued                                                            NaN
# property_search_warrant                                                     0
# void_count                                                                NaN
# bicycle_pmd                                                                 0
# property_search_pat_down                                                    0
# property_search_consent                                                     0
# person_srch_prob_cause                                                    NaN
# person_search_prob_cause                                                    0
# ticket_count                                                              NaN
# person_search_consent                                                       0
# date                                                2019-07-22 11:27:00+00:00
# month_year                                                2019-07-01 00:00:00
# year                                                      2019-01-01 00:00:00
#
#                                                                             2  \
# stop_reason_nonticket                                     Warrant/court order
# ethnicity                                                               Black
# stop_reason_ticket                                                        NaN
# stop_type                                                     Non-ticket Stop
# age                                                                      33.0
# pedestrian                                                                  0
# prop_srch_reason_consent                                                  NaN
# prop_srch_reason_warrant                                                  NaN
# prop_pat_down_obj_seized                                                  NaN
# prop_pat_down_obj                                                         NaN
# harbor                                                                      0
# gis_id                                                       Stop_Incidents_3
# objectid                                                               492163
# stop_district                                                              7D
# stop_reason_harbor                                                        NaN
# property_prot_pat_down                                                      0
# person_search_rea_consent                                                 NaN
# warning_count                                                             NaN
# prop_srch_obj_warrant                                                     NaN
# prop_pat_down_reason                                                      NaN
# person_srch_obj_prob_cause                                                NaN
# prop_srch_obj_seize_cause                                                 NaN
# person_search_pat_down                                                      0
# person_srch_reason_warrant                                                NaN
# gender                                                                 Female
# prop_search_obj_warrant                                                   NaN
# voided_tickets                                                            NaN
# arrest_charges                                  Probation Violation (Warrant)
# globalid                               {C8B860DB-79A3-44A2-BB28-C38620F838EC}
# property_srch_obj_consent                                                 NaN
# per_pro_pat_down_obj_seize                                                NaN
# stop_duration_mins                                                        1.0
# warnings_issued                                                           NaN
# vehicle                                                                     0
# person_search_warrant                                                       0
# person_srch_obj_seized_war                                                NaN
# prop_srch_prob_cause                                                      NaN
# prop_srch_obj_seize_con                                                   NaN
# arrest_date                                            2019/07/22 04:00:00+00
# prop_srch_obj_prob_cause                                                  NaN
# investigative                                                               1
# datetime                                               2019/07/22 10:50:00+00
# person_srch_obj_seized_con                                                NaN
# ccn_anonymized              0x6E47B8465054475BE2B3CF8C7972F09A173691E3D5BA...
# property_search_prob_cause                                                  0
# person_pat_down_reason                                                    NaN
# traffic_involved                                                            0
# person_prot_pat_down                                                        0
# tickets_issued                                                            NaN
# property_search_warrant                                                     0
# void_count                                                                NaN
# bicycle_pmd                                                                 0
# property_search_pat_down                                                    0
# property_search_consent                                                     0
# person_srch_prob_cause                                                    NaN
# person_search_prob_cause                                                    0
# ticket_count                                                              NaN
# person_search_consent                                                       0
# date                                                2019-07-22 10:50:00+00:00
# month_year                                                2019-07-01 00:00:00
# year                                                      2019-01-01 00:00:00
#
#                                                                             3  \
# stop_reason_nonticket                                     Warrant/court order
# ethnicity                                                               Black
# stop_reason_ticket                                                        NaN
# stop_type                                                     Non-ticket Stop
# age                                                                      55.0
# pedestrian                                                                  0
# prop_srch_reason_consent                                                  NaN
# prop_srch_reason_warrant                                                  NaN
# prop_pat_down_obj_seized                                                  NaN
# prop_pat_down_obj                                                         NaN
# harbor                                                                      0
# gis_id                                                       Stop_Incidents_4
# objectid                                                               492164
# stop_district                                                              7D
# stop_reason_harbor                                                        NaN
# property_prot_pat_down                                                      0
# person_search_rea_consent                                                 NaN
# warning_count                                                             NaN
# prop_srch_obj_warrant                                                     NaN
# prop_pat_down_reason                                                      NaN
# person_srch_obj_prob_cause                                                NaN
# prop_srch_obj_seize_cause                                                 NaN
# person_search_pat_down                                                      0
# person_srch_reason_warrant                                                NaN
# gender                                                                   Male
# prop_search_obj_warrant                                                   NaN
# voided_tickets                                                            NaN
# arrest_charges                                     Parole Violation (Warrant)
# globalid                               {441D451A-4800-474F-8B43-5FE0537D7B0E}
# property_srch_obj_consent                                                 NaN
# per_pro_pat_down_obj_seize                                                NaN
# stop_duration_mins                                                        1.0
# warnings_issued                                                           NaN
# vehicle                                                                     0
# person_search_warrant                                                       0
# person_srch_obj_seized_war                                                NaN
# prop_srch_prob_cause                                                      NaN
# prop_srch_obj_seize_con                                                   NaN
# arrest_date                                            2019/07/22 04:00:00+00
# prop_srch_obj_prob_cause                                                  NaN
# investigative                                                               1
# datetime                                               2019/07/22 10:39:00+00
# person_srch_obj_seized_con                                                NaN
# ccn_anonymized              0x69889283B23CF88C1600DA5BD333CA5CD7263F58E0EA...
# property_search_prob_cause                                                  0
# person_pat_down_reason                                                    NaN
# traffic_involved                                                            0
# person_prot_pat_down                                                        0
# tickets_issued                                                            NaN
# property_search_warrant                                                     0
# void_count                                                                NaN
# bicycle_pmd                                                                 0
# property_search_pat_down                                                    0
# property_search_consent                                                     0
# person_srch_prob_cause                                                    NaN
# person_search_prob_cause                                                    0
# ticket_count                                                              NaN
# person_search_consent                                                       0
# date                                                2019-07-22 10:39:00+00:00
# month_year                                                2019-07-01 00:00:00
# year                                                      2019-01-01 00:00:00
#
#                                                                             4
# stop_reason_nonticket                                     Warrant/court order
# ethnicity                                                            Hispanic
# stop_reason_ticket                                                        NaN
# stop_type                                                     Non-ticket Stop
# age                                                                      29.0
# pedestrian                                                                  0
# prop_srch_reason_consent                                                  NaN
# prop_srch_reason_warrant                                                  NaN
# prop_pat_down_obj_seized                                                  NaN
# prop_pat_down_obj                                                         NaN
# harbor                                                                      0
# gis_id                                                       Stop_Incidents_5
# objectid                                                               492165
# stop_district                                                              6D
# stop_reason_harbor                                                        NaN
# property_prot_pat_down                                                      0
# person_search_rea_consent                                                 NaN
# warning_count                                                             NaN
# prop_srch_obj_warrant                                                     NaN
# prop_pat_down_reason                                                      NaN
# person_srch_obj_prob_cause                                                NaN
# prop_srch_obj_seize_cause                                                 NaN
# person_search_pat_down                                                      1
# person_srch_reason_warrant                    Warrant (warrant search only) ;
# gender                                                                   Male
# prop_search_obj_warrant                                                   NaN
# voided_tickets                                                            NaN
# arrest_charges                                     Parole Violation (Warrant)
# globalid                               {ABB86702-C077-46C2-9264-09EADA4A65B3}
# property_srch_obj_consent                                                 NaN
# per_pro_pat_down_obj_seize                                                NaN
# stop_duration_mins                                                        3.0
# warnings_issued                                                           NaN
# vehicle                                                                     0
# person_search_warrant                                                       1
# person_srch_obj_seized_war                                             None ;
# prop_srch_prob_cause                                                      NaN
# prop_srch_obj_seize_con                                                   NaN
# arrest_date                                            2019/07/22 04:00:00+00
# prop_srch_obj_prob_cause                                                  NaN
# investigative                                                               1
# datetime                                               2019/07/22 11:57:00+00
# person_srch_obj_seized_con                                                NaN
# ccn_anonymized              0xA630FAD3F2DD45C542E07032FE9753AE79DCEE019581...
# property_search_prob_cause                                                  0
# person_pat_down_reason                                                    NaN
# traffic_involved                                                            0
# person_prot_pat_down                                                        0
# tickets_issued                                                            NaN
# property_search_warrant                                                     0
# void_count                                                                NaN
# bicycle_pmd                                                                 0
# property_search_pat_down                                                    0
# property_search_consent                                                     0
# person_srch_prob_cause                                                    NaN
# person_search_prob_cause                                                    0
# ticket_count                                                              NaN
# person_search_consent                                                       0
# date                                                2019-07-22 11:57:00+00:00
# month_year                                                2019-07-01 00:00:00
# year                                                      2019-01-01 00:00:00

# %%
arrest_data.head().T
# Out:
#                                                                     0  \
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/11/14 05:00:00+00
# hour                                                                6
# ccn                 45bb932cb42f1bba872a8dfcfb2428a10d6fe0598a63f2...
# arrest_number       1057043c3187ebc5c85920edbb441300e1446d3764e70f...
# age                                                                37
# defendant_psa                                            Out of State
# defendant_district                                       Out of State
# race                                                            WHITE
# ethnicity                                                NOT HISPANIC
# sex                                                              MALE
# category                                                    Sex Abuse
# description                      Second Degree Sex Abuse- Incompetent
# arrest_psa                                                      102.0
# arrest_district                                                    1D
# arrest_blockx                                                398600.0
# arrest_blocky                                                136300.0
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       NaN
# offense_district                                                  NaN
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_1
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {80CA3650-32C9-42C6-8412-9250D0E433BF}
# objectid                                                          1.0
# date                                        2013-11-14 05:00:00+00:00
# month_year                                        2013-11-01 00:00:00
#
#                                                                     1  \
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/11/20 05:00:00+00
# hour                                                               15
# ccn                 d558ea651a7b32e88571a453ccdf39376b2ec9dfb11f3c...
# arrest_number       ad3f22534b1e2c409d66328bb4ac3904e9bacc768c6091...
# age                                                                39
# defendant_psa                                                     602
# defendant_district                                                 6D
# race                                                            BLACK
# ethnicity                                                         NaN
# sex                                                              MALE
# category                                                     Homicide
# description                                                  Murder I
# arrest_psa                                                      602.0
# arrest_district                                                    6D
# arrest_blockx                                                405900.0
# arrest_blocky                                                137300.0
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       602
# offense_district                                                   6D
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_2
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {F1B2E42E-38B5-49D6-8A60-BF8CF0690A12}
# objectid                                                          2.0
# date                                        2013-11-20 05:00:00+00:00
# month_year                                        2013-11-01 00:00:00
#
#                                                                     2  \
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/12/03 05:00:00+00
# hour                                                                0
# ccn                 85451f87475b042563ddebc20b89b7258f07bca9b55b77...
# arrest_number       a723e9f1d0b44a6e0cef81994b8e7d3d3da55270e6f871...
# age                                                                40
# defendant_psa                                            Out of State
# defendant_district                                       Out of State
# race                                                            BLACK
# ethnicity                                                         NaN
# sex                                                              MALE
# category                                                 Prostitution
# description                                    Solicting Prostitution
# arrest_psa                                                      103.0
# arrest_district                                                    1D
# arrest_blockx                                                399200.0
# arrest_blocky                                                137200.0
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       NaN
# offense_district                                                  NaN
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_3
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {7F8BA37F-51F5-437F-A8F4-4B755385797B}
# objectid                                                          3.0
# date                                        2013-12-03 05:00:00+00:00
# month_year                                        2013-12-01 00:00:00
#
#                                                                     3  \
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/12/05 05:00:00+00
# hour                                                               21
# ccn                 3498c726acd19b8fc48c50a86c4e21e5823c41722cb779...
# arrest_number       1a94d5a92f8538d3252aa65690ab70fac1a67646eb22ee...
# age                                                                65
# defendant_psa                                                     502
# defendant_district                                                 5D
# race                                                            BLACK
# ethnicity                                                         NaN
# sex                                                              MALE
# category                                                      rcotics
# description                                          Ucsa Pwid Heroin
# arrest_psa                                                      102.0
# arrest_district                                                    1D
# arrest_blockx                                                398400.0
# arrest_blocky                                                136900.0
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       NaN
# offense_district                                                  NaN
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_4
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {70B94138-C9F4-4CFF-9A72-12B071F3A78C}
# objectid                                                          4.0
# date                                        2013-12-05 05:00:00+00:00
# month_year                                        2013-12-01 00:00:00
#
#                                                                     4
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/12/09 05:00:00+00
# hour                                                               23
# ccn                 88e342ab716f545b67c467914d6999d514ec6ea34d5c2e...
# arrest_number       5a0e432aaa38e011a7b8aa29de617d4e635acab29b3db5...
# age                                                                31
# defendant_psa                                                     702
# defendant_district                                                 7D
# race                                                            BLACK
# ethnicity                                                NOT HISPANIC
# sex                                                              MALE
# category                                           Traffic Violations
# description                                                 No Permit
# arrest_psa                                                      204.0
# arrest_district                                                    2D
# arrest_blockx                                                     NaN
# arrest_blocky                                                     NaN
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       NaN
# offense_district                                                  NaN
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_5
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {2DCB5E7E-311F-48B8-A36B-BF1D6C2890F5}
# objectid                                                          5.0
# date                                        2013-12-09 05:00:00+00:00
# month_year                                        2013-12-01 00:00:00

# %%
officer_data
# Out:
#          year  officers
# 0  1999-01-01      3466
# 1  2000-01-01      3628
# 2  2001-01-01      3616
# 3  2002-01-01      3637
# 4  2003-01-01      3664
# 5  2004-01-01      3800
# 6  2005-01-01      3801
# 7  2006-01-01      3800
# 8  2007-01-01      3910
# 9  2008-01-01      4051
# 10 2009-01-01      4032
# 11 2010-01-01      3961
# 12 2011-01-01      3801
# 13 2012-01-01      3899
# 14 2013-01-01      4010
# 15 2014-01-01      3972
# 16 2015-01-01      3837
# 17 2016-01-01      3737
# 18 2017-01-01      3821
# 19 2018-01-01      3855
# 20 2019-01-01      3810
# 21 2020-01-01      3799
# 22 2021-01-01      3580
# 23 2022-01-01      3460
# 24 2023-01-01      3337
# 25 2024-01-01      3337

# %% [markdown]
# ## Data Ranges

# %%
[(d.year.min(), d.year.max()) for d in [incident_data, stop_data, arrest_data]]
# Out:
# [(Timestamp('1800-01-01 00:00:00'), Timestamp('2024-01-01 00:00:00')),
#  (Timestamp('2019-01-01 00:00:00'), Timestamp('2024-01-01 00:00:00')),
#  (Timestamp('2013-01-01 00:00:00'), Timestamp('2023-01-01 00:00:00'))]

# %%
[(d.date.min(), d.date.max()) for d in [incident_data, stop_data, arrest_data]]
# Out:
# [(Timestamp('1800-01-15 19:08:58+0000', tz='UTC'),
#   Timestamp('2024-03-18 03:15:00+0000', tz='UTC')),
#  (Timestamp('2019-07-22 04:00:00+0000', tz='UTC'),
#   Timestamp('2024-01-01 04:32:00+0000', tz='UTC')),
#  ('2013-01-01 05:00:00+00:00', '2023-12-31 00:00:00')]

# %% [markdown]
# ## MPD Staffing

# %%
sns.set(rc={"figure.figsize": (14, 6)})
sns.barplot(
    data=officer_data,
    x=officer_data.year.dt.strftime("%Y"),  # hack
    y="officers",
    color="navy",
    width=0.4,
).set(title="MPD Historical Sworn Staffing")
# Out:
# [Text(0.5, 1.0, 'MPD Historical Sworn Staffing')]

# %% [markdown]
# ## Scale Incident Data to 2019

# %%
incidents_by_month = (
    incident_data.groupby(["month_year", "offense"]).ccn.count().reset_index()
)

# %%
# fix this if older data is added
incidents_by_month = incidents_by_month[
    (incidents_by_month.month_year > "2015-12")
    & (incidents_by_month.month_year < "2024-03")
]

# very few arsons, just dropping this
incidents_by_month = incidents_by_month[incidents_by_month.offense != "arson"]

# %%
incidents_by_month.columns = ["Date", "Offense", "Count"]

# %%
incidents_by_month.tail(20)
# Out:
#            Date                     Offense  Count
# 1158 2023-12-01                THEFT F/AUTO    619
# 1159 2023-12-01                 THEFT/OTHER   1080
# 1160 2024-01-01                       ARSON      1
# 1161 2024-01-01  ASSAULT W/DANGEROUS WEAPON     78
# 1162 2024-01-01                    BURGLARY     76
# 1163 2024-01-01                    HOMICIDE     11
# 1164 2024-01-01         MOTOR VEHICLE THEFT    435
# 1165 2024-01-01                     ROBBERY    216
# 1166 2024-01-01                   SEX ABUSE     19
# 1167 2024-01-01                THEFT F/AUTO    526
# 1168 2024-01-01                 THEFT/OTHER    999
# 1169 2024-02-01                       ARSON      1
# 1170 2024-02-01  ASSAULT W/DANGEROUS WEAPON     69
# 1171 2024-02-01                    BURGLARY     58
# 1172 2024-02-01                    HOMICIDE     16
# 1173 2024-02-01         MOTOR VEHICLE THEFT    350
# 1174 2024-02-01                     ROBBERY    175
# 1175 2024-02-01                   SEX ABUSE     11
# 1176 2024-02-01                THEFT F/AUTO    483
# 1177 2024-02-01                 THEFT/OTHER    958

# %%
incidents_2019_monthly_averages = (
    incidents_by_month[
        incidents_by_month.Date.dt.strftime("%Y") == "2019"
    ]  # wrong way to do this
    .groupby("Offense")
    .agg({"Count": "mean"})
    .to_dict()
)[
    "Count"
]  # hack to get rid of nested dict

# %%
incidents_by_month["Normalized Count"] = incidents_by_month.apply(
    lambda x: x["Count"] / incidents_2019_monthly_averages[x["Offense"]], axis=1
)

# %%
# sanity check
incidents_2019_monthly_averages
# Out:
# {'ARSON': 2.0,
#  'ASSAULT W/DANGEROUS WEAPON': 130.91666666666666,
#  'BURGLARY': 105.66666666666667,
#  'HOMICIDE': 13.666666666666666,
#  'MOTOR VEHICLE THEFT': 182.83333333333334,
#  'ROBBERY': 186.08333333333334,
#  'SEX ABUSE': 16.416666666666668,
#  'THEFT F/AUTO': 892.8333333333334,
#  'THEFT/OTHER': 1290.6666666666667}

# %% [markdown]
# ## Incidents by Type

# %%
sns.set(rc={"figure.figsize": (14, 6)})
g = sns.lineplot(
    data=incidents_by_month[
        incidents_by_month.Offense.isin(
            ["ASSAULT W/DANGEROUS WEAPON", "HOMICIDE", "ROBBERY", "SEX ABUSE"]
        )
    ],
    x="Date",
    y="Count",
    hue="Offense",
)

# %%
# Too busy and needs the x fixed
sns.set(rc={"figure.figsize": (14, 6)})
g = sns.lineplot(data=incidents_by_month, x="Date", y="Normalized Count", hue="Offense")

# %%
# Break out invariant reporting and other types of crimes
incidents_by_month["Crime Type"] = [
    i if i in ["HOMICIDE", "MOTOR VEHICLE THEFT"] else "Other Crimes"
    for i in incidents_by_month.Offense
]

incidents_by_month = incidents_by_month.sort_values(["Offense", "Date"]).reset_index(
    drop=True
)  # hack for graph ordering

# %%
incidents_by_month = incidents_by_month[
    incidents_by_month.Offense != "ARSON"
].reset_index(
    drop=True
)  # too few of these, makes a mess

# %%
# This equal weights the crime categories rather than summing counts of all crimes in these categories and normalizing that.
# Could make a good argument for doing it either way but this way is easier for now.
incidents_by_month_rollup = (
    incidents_by_month.groupby(["Date", "Crime Type"])["Normalized Count"]
    .mean()
    .reset_index()
    .sort_values(["Crime Type", "Date"])
    .reset_index(drop=True)
)

# %%
incidents_by_month_rollup["Normalized Count 6 Month Rolling Avg"] = (
    incidents_by_month_rollup.groupby("Crime Type")
    .rolling(6, 1)["Normalized Count"]
    .mean()
    .reset_index(drop=True)
)

# %%
incidents_by_month["Normalized Count 6 Month Rolling Avg"] = (
    incidents_by_month.groupby("Offense")
    .rolling(6, 1)["Normalized Count"]
    .mean()
    .reset_index(drop=True)
)

# %%
# labels still bad but it makes the point
sns.set(rc={"figure.figsize": (14, 6)})
g = sns.lineplot(
    data=incidents_by_month_rollup,
    x="Date",
    y="Normalized Count 6 Month Rolling Avg",
    hue="Crime Type",
    errorbar=None,
)
g.axhline(y=1, ls="--", c="green")
g.set(
    title="Crime Incidents per Month, Homicide and Car Theft vs. Others (normalized to 2019)"
)
# Out:
# [Text(0.5, 1.0, 'Crime Incidents per Month, Homicide and Car Theft vs. Others (normalized to 2019)')]

# %%
# facet grid instead
sns.set(rc={"figure.figsize": (14, 6)})
g = sns.FacetGrid(data=incidents_by_month, row="Crime Type", height=2, aspect=6)
g.set(
    xlim=(incidents_by_month.Date.min(), incidents_by_month.Date.max())
)  # something is broken, this is a hack
g.set(ylim=(0.4, 2.4))
g.map(plt.axhline, y=1, ls="--", c="orange")
g.map(plt.axvline, x=pd.to_datetime("2020-04-01"), ls="--", c="green")
g.map_dataframe(
    sns.lineplot, x="Date", y="Normalized Count 6 Month Rolling Avg", errorbar=None
)
g.add_legend()
g.set(
    title="Crime Incidents per Month (6 month rolling average), Homicide and Car Theft vs. Others (normalized to 2019)"
)

# %%
# facet grid of all offense types
sns.set(rc={"figure.figsize": (14, 6)})
g = sns.FacetGrid(data=incidents_by_month, row="Offense", height=2, aspect=6)
g.set(
    xlim=(incidents_by_month.Date.min(), incidents_by_month.Date.max())
)  # something is broken, this is a hack
g.set(ylim=(0.4, 2.4))
g.map(plt.axhline, y=1, ls="--", c="orange")
g.map(plt.axvline, x=pd.to_datetime("2020-04-01"), ls="--", c="green")
g.map_dataframe(sns.lineplot, x="Date", y="Normalized Count")
g.add_legend()

# %% [markdown]
# ## Stop Data

# %%
stop_data = pd.read_csv(
    "../data/clean/stop_data.csv.gz",
    parse_dates=["date", "year", "month_year"],
    low_memory=False,
)

# %%
# this has been added to ETL.py, need to remove here once set up and run
def stop_reason_nonticket_cleanup(df: pd.DataFrame) -> pd.DataFrame:
    """
    Stop reasons have a bunch of errors.
    Doing this line by line for clarity.
    """
    df["stop_reason_nonticket"] = (
        df.stop_reason_nonticket.fillna("").apply(str).apply(lambda x: x.strip())
    )
    df["stop_reason_nonticket"] = df.stop_reason_nonticket.str.replace(
        "<U+0092>", "'"
    ).str.replace("<U+FFFD>", "'")
    return df

# %%
stop_data = stop_reason_nonticket_cleanup(stop_data)

# %%
# This is a mess and needs cleanup
stop_data.stop_reason_nonticket.value_counts()
# Out:
# stop_reason_nonticket
#                                                                                                                                                         201627
# Call for service                                                                                                                                         50331
# Traffic violation                                                                                                                                        13384
# Warrant/court order                                                                                                                                      11777
# BOLO/Lookout                                                                                                                                              8289
#                                                                                                                                                          ...
# Information obtained from law enforcement sources; Prior knowledge; Traffic violation                                                                        1
# Warrant/court order; BOLO/Lookout; Information obtained from law enforcement sources; Prior knowledge                                                        1
# Individual's actions; BOLO/Lookout; Suspicion of criminal activity (self-initiated); Observed a weapon                                                       1
# Suspicion of criminal activity (self-initiated); Prior knowledge; Information obtained from law enforcement sources; Demeanor during a field contact         1
# Individual’s actions, Individual’s characteristics, Medical/Behavioral Health Event, Suspicion of criminal activity (self-initiated)                         1
# Name: count, Length: 2667, dtype: int64

# %%
stop_data.stop_reason_ticket.value_counts().head()
# Out:
# stop_reason_ticket
# Observed moving violation       157158
# Observed equipment violation     18243
# Calls for service                12775
# Response to Crash                10537
# BOLO/Lookout                       468
# Name: count, dtype: int64

# %%
g = (
    stop_data[
        (stop_data.stop_reason_nonticket == "Call for service")
        | (stop_data.stop_reason_ticket == "Calls for service")
    ]
    .groupby("month_year")
    .objectid.count()[1:-1]
    .plot()
)  # [1:-1] to remove incomplete months

g.set(
    title="MPD Stops Recorded as Call for Service per Month",
    xlabel=None,
    ylim=(0, None),
)
# Out:
# [Text(0.5, 1.0, 'MPD Stops Recorded as Call for Service per Month'),
#  Text(0.5, 0, ''),
#  (0.0, 1655.8)]

# %%
g = (
    stop_data.groupby("month_year").objectid.count()[1:-1].plot()
)  # [1:-1] to remove incomplete months

g.set(title="MPD Stops per Month", xlabel=None, ylim=(0, None))
# Out:
# [Text(0.5, 1.0, 'MPD Stops per Month'), Text(0.5, 0, ''), (0.0, 14080.4)]

# %%
stop_data.groupby(
    ["month_year", "stop_reason_nonticket"]
).objectid.count().reset_index()[1:-1]
# Out:
#      month_year                              stop_reason_nonticket  objectid
# 1    2019-07-01                                       BOLO/Lookout        70
# 2    2019-07-01                     BOLO/Lookout; Call for service        21
# 3    2019-07-01  BOLO/Lookout; Call for service; Individual's a...         1
# 4    2019-07-01  BOLO/Lookout; Call for service; Individual's c...         1
# 5    2019-07-01  BOLO/Lookout; Call for service; Information ob...         2
# ...         ...                                                ...       ...
# 9206 2023-12-01    Suspicion of criminal activity (self-initiated)       131
# 9207 2023-12-01  Suspicion of criminal activity (self-initiated...         6
# 9208 2023-12-01                                  Traffic violation       162
# 9209 2023-12-01                                            Truancy        93
# 9210 2023-12-01                                Warrant/court order       208
#
# [9210 rows x 3 columns]

# %%
g = (
    stop_data[stop_data.stop_reason_ticket == "Observed equipment violation"]
    .groupby("month_year")
    .objectid.count()[1:]
    .plot()
)  # [1:] to remove an incomplete month
g.set(
    title="MPD Observed Equipment Violation Stops per Month",
    xlabel=None,
    ylim=(0, None),
)
# Out:
# [Text(0.5, 1.0, 'MPD Observed Equipment Violation Stops per Month'),
#  Text(0.5, 0, ''),
#  (0.0, 1209.25)]

# %%
g = (
    stop_data[stop_data.stop_reason_ticket == "Observed moving violation"]
    .groupby("month_year")
    .objectid.count()[1:-1]
    .plot()
)  # [1:-1] to remove incomplete months
g.set(
    title="MPD Observed Moving Violation Stops per Month",
    xlabel=None,
    ylim=(0, None),
)
# Out:
# [Text(0.5, 1.0, 'MPD Observed Moving Violation Stops per Month'),
#  Text(0.5, 0, ''),
#  (0.0, 7690.6)]

# %%
def create_stop_reason_combined(row):
    # Slow but whatev.
    if pd.notna(row["stop_reason_ticket"]):
        return row["stop_reason_ticket"]
    elif (
        pd.notna(row["stop_reason_nonticket"]) & len(str(row["stop_reason_nonticket"]))
        > 0
    ):
        return row["stop_reason_nonticket"] + " (nonticket)"
    else:
        return "Unknown"

# %%
stop_data["stop_reason_combined"] = stop_data.apply(create_stop_reason_combined, axis=1)

# %%
stop_data.stop_reason_combined.value_counts().head(17)
# Out:
# stop_reason_combined
# Observed moving violation                                                          157158
# Unknown                                                                             90089
# Observed equipment violation                                                        18243
# Calls for service                                                                   12775
# Warrant/court order (nonticket)                                                     11768
# Response to Crash                                                                   10537
# Traffic violation (nonticket)                                                       10115
# Suspicion of criminal activity (self-initiated) (nonticket)                          6411
# Information obtained from law enforcement sources (nonticket)                        5110
# Individuals actions (nonticket)                                                      3863
# Information obtained from witnesses or informants (nonticket)                        2895
# Prior knowledge (nonticket)                                                          1883
# Demeanor during a field contact (nonticket)                                           886
# Observed a weapon (nonticket)                                                         632
# Response to crash (nonticket)                                                         613
# Call for service, Individuals actions (nonticket)                                     511
# Call for service, Information obtained from witnesses or informants (nonticket)       496
# Name: count, dtype: int64

# %%
stop_data_top_reasons = stop_data[
    stop_data.stop_reason_combined.isin(
        stop_data.stop_reason_combined.value_counts().head(4).index
    )
]

# %%
stop_data_top_reasons.groupby(["stop_reason_combined", "month_year"]).objectid.count().reset_index().to_clipboard()

# %%
stop_data.pivot_table(index="month_year", values="objectid", aggfunc="count")[1:-1].plot()
# Out:
# <Axes: xlabel='month_year'>

# %%
stop_data_top_reasons.pivot_table(columns="stop_reason_combined", index="month_year", values="objectid", aggfunc="count")[1:-1].plot()
# Out:
# <Axes: xlabel='month_year'>

# %%
stop_data.stop_reason_combined.value_counts().head()
# Out:
# stop_reason_combined
# Observed moving violation          157158
# Unknown                             90089
# Observed equipment violation        18243
# Calls for service                   12775
# Warrant/court order (nonticket)     11768
# Name: count, dtype: int64

# %%
stop_data.groupby(["stop_reason_ticket", "stop_reason_nonticket"], dropna=False).objectid.count().reset_index().sort_values("objectid", ascending=False).head(10)
# Out:
#                 stop_reason_ticket  \
# 168      Observed moving violation
# 883                            NaN
# 114   Observed equipment violation
# 24               Calls for service
# 2950                           NaN
# 308              Response to Crash
# 2868                           NaN
# 401                            NaN
# 1485                           NaN
# 2667                           NaN
#
#                                 stop_reason_nonticket  objectid
# 168                                                      154026
# 883                                  Call for service     50075
# 114                                                       17546
# 24                                                        12501
# 2950                              Warrant/court order     11768
# 308                                                       10205
# 2868                                Traffic violation     10115
# 401                                      BOLO/Lookout      8252
# 1485                             Individual's actions      8023
# 2667  Suspicion of criminal activity (self-initiated)      6411

# %%
fig, ax = plt.subplots(figsize=(9, 6))
sns.lineplot(
    stop_data_top_reasons.groupby(["stop_reason_combined", "month_year"])
    .objectid.count()
    .reset_index(),
    x="month_year",
    y="objectid",
    hue="stop_reason_combined",
    ax=ax
)
# Out:
# <Axes: xlabel='month_year', ylabel='objectid'>

# %% [markdown]
# ## Arrest Data

# %%
# temporary fix because I don't want to re-run ETL


def arrest_category_cleanup(df: pd.DataFrame) -> pd.DataFrame:
    """
    Data through 2017 has "Na" dropped from the strings in the category field,
    replaced with a single space.
    Like Dave says, if you don't have the right tools, don't use a spoon.
    This also corrects an unrelated errors in the Release Violations and
    Fraud/Financial categories, rolling up a few random values.
    """
    fixes = {
        " rcotics": "Narcotics",
        "Fraud and Fi ncial Crimes": "Fraud and Financial Crimes",
        "Fraud and Financial Crimes (Coun)": "Fraud and Financial Crimes",
        "Fraud and Financial Crimes (Forg)": "Fraud and Financial Crimes",
        "Fraud and Financial Crimes (Frau)": "Fraud and Financial Crimes",
        "Kid pping": "Kidnapping",
        "Release Violations/Fugitive (Fug)": "Release Violations/Fugitive",
        "Release Violations/Fugitive (Warr)": "Release Violations/Fugitive",
        "Release Violations": "Release Violations/Fugitive",
    }

    df["category"] = df.category.apply(lambda x: fixes.get(x, x))
    return df

# %%
arrest_data = arrest_category_cleanup(arrest_data)

# %%
sns.set(rc={"figure.figsize": (14, 6)})
g = arrest_data.groupby("month_year").ccn.count().plot()
g.set(
    title="MPD Monthly Arrests",
    xlabel=None,
    ylim=(0, None),
)
# Out:
# [Text(0.5, 1.0, 'MPD Monthly Arrests'), Text(0.5, 0, ''), (0.0, 3313.45)]

# %%
# Quick and dirty monthly dataset
incidents_monthly = incident_data.groupby("month_year").ccn.count()[
    85:-1
]  # manually trim some BS
stops_monthly = stop_data.groupby("month_year").objectid.count()[1:-1]
arrests_monthly = arrest_data.groupby("month_year").ccn.count()

# %%
monthly_summary = pd.concat(
    [incidents_monthly, stops_monthly, arrests_monthly], axis=1
).reset_index()
monthly_summary.columns = ["Month", "Incidents", "Stops", "Arrests"]

# %%
monthly_summary["Year"] = monthly_summary.Month.dt.year

# %%
monthly_summary = monthly_summary[["Year", "Month", "Incidents", "Stops", "Arrests"]]

# %%
officers_annual_dict = dict(zip(officer_data.year.dt.year, officer_data.officers))

# %%
monthly_summary["Sworn Officers"] = [
    officers_annual_dict[y] for y in monthly_summary.Year
]

# %%
monthly_summary["Incidents per Officer per Month"] = (
    monthly_summary.Incidents / monthly_summary["Sworn Officers"]
)
monthly_summary["Stops per Officer per Month"] = (
    monthly_summary.Stops / monthly_summary["Sworn Officers"]
)
monthly_summary["Arrests per Officer per Month"] = (
    monthly_summary.Arrests / monthly_summary["Sworn Officers"]
)

# %%
monthly_summary_rates = pd.melt(
    monthly_summary[
        [
            "Month",
            "Incidents per Officer per Month",
            "Stops per Officer per Month",
            "Arrests per Officer per Month",
        ]
    ],
    "Month",
)

# %%
sns.set(rc={"figure.figsize": (6, 4)})

sns.lineplot(
    data=monthly_summary_rates[
        (monthly_summary_rates.Month > "2017-12-01")
        & (monthly_summary_rates.variable != "Incidents per Officer per Month")
    ],
    x="Month",
    y="value",
    hue="variable",
)
# Out:
# <Axes: xlabel='Month', ylabel='value'>

# %%
arrests_year_category = (
    arrest_data.groupby(["year", "category"]).ccn.count().reset_index()
)
arrests_year_category.pivot(
    columns="year", index="category", values="ccn"
).to_clipboard()
# manual cleanup done here: https://docs.google.com/spreadsheets/d/1N7FVH9PqlW8NjiL6RcXTV7vrrWRhN4aLlYmYrWlEXXM/edit?usp=sharing

# %%
arrests_year_category.pivot(columns="year", index="category", values="ccn")
# Out:
# year                                2013-01-01  2014-01-01  2015-01-01  \
# category
# Aggravated Assault                       284.0       282.0       235.0
# Arson                                      3.0         6.0         6.0
# Assault on a Police Officer              839.0       855.0       749.0
# Assault with a Dangerous Weapon         1239.0      1277.0      1155.0
# Burglary                                 243.0       248.0       198.0
# Damage to Property                       588.0       675.0       706.0
# Disorderly Conduct                       890.0       852.0       656.0
# Driving/Boating While Intoxicated       1311.0      1337.0      1078.0
# Fraud and Financial Crimes               518.0       223.0       148.0
# Gambling                                 136.0       192.0       129.0
# Homicide                                  75.0        68.0        99.0
# Kidnapping                                35.0        34.0        21.0
# Liquor Law Violations                   1530.0      1451.0      1111.0
# Motor Vehicle Theft                       34.0        34.0        47.0
# Narcotics                               4540.0      4210.0      2094.0
# Offenses Against Family & Children       179.0       191.0       211.0
# Other Crimes                            1141.0      1216.0      1331.0
# Property Crimes                          590.0       596.0       534.0
# Prostitution                             847.0       577.0       713.0
# Release Violations/Fugitive             4972.0      4385.0      3796.0
# Robbery                                  659.0       526.0       523.0
# Sex Abuse                                 90.0        78.0        79.0
# Sex Offenses                             209.0       216.0       228.0
# Simple Assault                          5624.0      6135.0      6072.0
# Theft                                   1458.0      1935.0      1872.0
# Theft from Auto                          109.0       117.0        73.0
# Traffic Violations                      3589.0      3957.0      2989.0
# Vending Violations                       307.0       102.0        94.0
# Weapon Violations                        466.0       522.0       706.0
#
# year                                2016-01-01  2017-01-01  2018-01-01  \
# category
# Aggravated Assault                       194.0       174.0       133.0
# Arson                                      5.0         4.0         4.0
# Assault on a Police Officer              606.0       438.0       405.0
# Assault with a Dangerous Weapon         1058.0       860.0       785.0
# Burglary                                 279.0       241.0       182.0
# Damage to Property                       822.0       814.0       738.0
# Disorderly Conduct                       628.0       757.0       469.0
# Driving/Boating While Intoxicated       1307.0      1306.0      1475.0
# Fraud and Financial Crimes               149.0       144.0       163.0
# Gambling                                 116.0        94.0        72.0
# Homicide                                  84.0        81.0        95.0
# Kidnapping                                14.0        10.0        23.0
# Liquor Law Violations                    983.0       886.0       632.0
# Motor Vehicle Theft                       39.0        42.0        24.0
# Narcotics                               2803.0      3192.0      2603.0
# Offenses Against Family & Children       304.0       326.0       303.0
# Other Crimes                            1566.0      1857.0      1752.0
# Property Crimes                          660.0       598.0       570.0
# Prostitution                             214.0       229.0       554.0
# Release Violations/Fugitive             4277.0      4500.0      4141.0
# Robbery                                  533.0       380.0       378.0
# Sex Abuse                                100.0        80.0        53.0
# Sex Offenses                             215.0       217.0       187.0
# Simple Assault                          6152.0      6201.0      5893.0
# Theft                                   1899.0      2043.0      1934.0
# Theft from Auto                           67.0        75.0        60.0
# Traffic Violations                      3739.0      4471.0      4420.0
# Vending Violations                        92.0       106.0        56.0
# Weapon Violations                       1075.0      1083.0       999.0
#
# year                                2019-01-01  2020-01-01  2021-01-01  \
# category
# Aggravated Assault                       139.0        91.0        97.0
# Arson                                      4.0         5.0         NaN
# Assault on a Police Officer              383.0       377.0       346.0
# Assault with a Dangerous Weapon          668.0       582.0       571.0
# Burglary                                 146.0       205.0       133.0
# Damage to Property                       691.0       668.0       623.0
# Disorderly Conduct                       352.0       236.0        65.0
# Driving/Boating While Intoxicated       1305.0       950.0       835.0
# Fraud and Financial Crimes               129.0        54.0        32.0
# Gambling                                  38.0        17.0        19.0
# Homicide                                  88.0       102.0        98.0
# Kidnapping                                18.0        10.0        25.0
# Liquor Law Violations                    478.0       179.0        95.0
# Motor Vehicle Theft                       39.0        42.0        22.0
# Narcotics                               2286.0      1252.0       702.0
# Offenses Against Family & Children       367.0       650.0       381.0
# Other Crimes                            1786.0       965.0       941.0
# Property Crimes                          522.0       512.0       431.0
# Prostitution                            1273.0       282.0        23.0
# Release Violations/Fugitive             3633.0      2109.0      1645.0
# Robbery                                  319.0       211.0       208.0
# Sex Abuse                                 48.0        34.0        44.0
# Sex Offenses                             172.0       121.0       139.0
# Simple Assault                          5899.0      4905.0      4876.0
# Theft                                   1766.0       766.0       675.0
# Theft from Auto                           76.0        44.0        36.0
# Traffic Violations                      4139.0      1856.0      1366.0
# Vending Violations                        52.0        34.0        10.0
# Weapon Violations                       1122.0      1232.0      1215.0
#
# year                                2022-01-01  2023-01-01
# category
# Aggravated Assault                        88.0       125.0
# Arson                                      4.0         6.0
# Assault on a Police Officer              311.0       300.0
# Assault with a Dangerous Weapon          475.0       409.0
# Burglary                                 117.0       117.0
# Damage to Property                       600.0       637.0
# Disorderly Conduct                       110.0       109.0
# Driving/Boating While Intoxicated        627.0       643.0
# Fraud and Financial Crimes                48.0        25.0
# Gambling                                   7.0         5.0
# Homicide                                 100.0       107.0
# Kidnapping                                10.0        17.0
# Liquor Law Violations                    102.0       165.0
# Motor Vehicle Theft                       31.0        32.0
# Narcotics                                736.0       538.0
# Offenses Against Family & Children       337.0       401.0
# Other Crimes                            1109.0      1064.0
# Property Crimes                          392.0       502.0
# Prostitution                              14.0        11.0
# Release Violations/Fugitive             1553.0      1588.0
# Robbery                                  171.0       189.0
# Sex Abuse                                 51.0        56.0
# Sex Offenses                             153.0       133.0
# Simple Assault                          4597.0      5085.0
# Theft                                    703.0       889.0
# Theft from Auto                           26.0        14.0
# Traffic Violations                       996.0       925.0
# Vending Violations                        42.0         8.0
# Weapon Violations                       1481.0      1441.0

# %%
stop_data.stop_reason_nonticket.value_counts().tail(10)
# Out:
# stop_reason_nonticket
# Demeanor during a field contact; Call for service; Individual<U+0092>s characteristics; Individual<U+0092>s actions; Suspicion of criminal activity (self-initiated)                      1
# Individual<U+0092>s actions; Call for service; BOLO/Lookout; Individual<U+0092>s characteristics                                                                                          1
# Observed a weapon; Call for service; Individual<U+0092>s actions; Demeanor during a field contact                                                                                         1
# Warrant/court order; Information obtained from law enforcement sources; Individual<U+0092>s actions; Call for service                                                                     1
# Information obtained from law enforcement sources; Observed a weapon; Call for service                                                                                                    1
# Suspicion of criminal activity (self-initiated); Traffic violation; Individual<U+0092>s characteristics; Demeanor during a field contact; Individual<U+0092>s actions; Prior knowledge    1
# BOLO/Lookout; Information obtained from law enforcement sources; Warrant/court order                                                                                                      1
# BOLO/Lookout; Traffic violation; Information obtained from law enforcement sources                                                                                                        1
# Information obtained from law enforcement sources; Information obtained from witnesses or informants; Prior knowledge; Call for service                                                   1
#  Individual’s actions, Individual’s characteristics, Medical/Behavioral Health Event, Suspicion of criminal activity (self-initiated)                                                     1
# Name: count, dtype: int64

# %%
arrest_data.head().T
# Out:
#                                                                     0  \
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/11/14 05:00:00+00
# hour                                                                6
# ccn                 45bb932cb42f1bba872a8dfcfb2428a10d6fe0598a63f2...
# arrest_number       1057043c3187ebc5c85920edbb441300e1446d3764e70f...
# age                                                                37
# defendant_psa                                            Out of State
# defendant_district                                       Out of State
# race                                                            WHITE
# ethnicity                                                NOT HISPANIC
# sex                                                              MALE
# category                                                    Sex Abuse
# description                      Second Degree Sex Abuse- Incompetent
# arrest_psa                                                      102.0
# arrest_district                                                    1D
# arrest_blockx                                                398600.0
# arrest_blocky                                                136300.0
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       NaN
# offense_district                                                  NaN
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_1
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {80CA3650-32C9-42C6-8412-9250D0E433BF}
# objectid                                                          1.0
# date                                        2013-11-14 05:00:00+00:00
# month_year                                        2013-11-01 00:00:00
#
#                                                                     1  \
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/11/20 05:00:00+00
# hour                                                               15
# ccn                 d558ea651a7b32e88571a453ccdf39376b2ec9dfb11f3c...
# arrest_number       ad3f22534b1e2c409d66328bb4ac3904e9bacc768c6091...
# age                                                                39
# defendant_psa                                                     602
# defendant_district                                                 6D
# race                                                            BLACK
# ethnicity                                                         NaN
# sex                                                              MALE
# category                                                     Homicide
# description                                                  Murder I
# arrest_psa                                                      602.0
# arrest_district                                                    6D
# arrest_blockx                                                405900.0
# arrest_blocky                                                137300.0
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       602
# offense_district                                                   6D
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_2
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {F1B2E42E-38B5-49D6-8A60-BF8CF0690A12}
# objectid                                                          2.0
# date                                        2013-11-20 05:00:00+00:00
# month_year                                        2013-11-01 00:00:00
#
#                                                                     2  \
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/12/03 05:00:00+00
# hour                                                                0
# ccn                 85451f87475b042563ddebc20b89b7258f07bca9b55b77...
# arrest_number       a723e9f1d0b44a6e0cef81994b8e7d3d3da55270e6f871...
# age                                                                40
# defendant_psa                                            Out of State
# defendant_district                                       Out of State
# race                                                            BLACK
# ethnicity                                                         NaN
# sex                                                              MALE
# category                                                 Prostitution
# description                                    Solicting Prostitution
# arrest_psa                                                      103.0
# arrest_district                                                    1D
# arrest_blockx                                                399200.0
# arrest_blocky                                                137200.0
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       NaN
# offense_district                                                  NaN
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_3
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {7F8BA37F-51F5-437F-A8F4-4B755385797B}
# objectid                                                          3.0
# date                                        2013-12-03 05:00:00+00:00
# month_year                                        2013-12-01 00:00:00
#
#                                                                     3  \
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/12/05 05:00:00+00
# hour                                                               21
# ccn                 3498c726acd19b8fc48c50a86c4e21e5823c41722cb779...
# arrest_number       1a94d5a92f8538d3252aa65690ab70fac1a67646eb22ee...
# age                                                                65
# defendant_psa                                                     502
# defendant_district                                                 5D
# race                                                            BLACK
# ethnicity                                                         NaN
# sex                                                              MALE
# category                                                    Narcotics
# description                                          Ucsa Pwid Heroin
# arrest_psa                                                      102.0
# arrest_district                                                    1D
# arrest_blockx                                                398400.0
# arrest_blocky                                                136900.0
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       NaN
# offense_district                                                  NaN
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_4
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {70B94138-C9F4-4CFF-9A72-12B071F3A78C}
# objectid                                                          4.0
# date                                        2013-12-05 05:00:00+00:00
# month_year                                        2013-12-01 00:00:00
#
#                                                                     4
# type                                                     Adult Arrest
# year                                              2013-01-01 00:00:00
# date_                                          2013/12/09 05:00:00+00
# hour                                                               23
# ccn                 88e342ab716f545b67c467914d6999d514ec6ea34d5c2e...
# arrest_number       5a0e432aaa38e011a7b8aa29de617d4e635acab29b3db5...
# age                                                                31
# defendant_psa                                                     702
# defendant_district                                                 7D
# race                                                            BLACK
# ethnicity                                                NOT HISPANIC
# sex                                                              MALE
# category                                           Traffic Violations
# description                                                 No Permit
# arrest_psa                                                      204.0
# arrest_district                                                    2D
# arrest_blockx                                                     NaN
# arrest_blocky                                                     NaN
# offense_blocky                                                    NaN
# offense_blockx                                                    NaN
# offense_psa                                                       NaN
# offense_district                                                  NaN
# arrest_latitude                                                   NaN
# arrest_longitude                                                  NaN
# offense_latitude                                                  NaN
# offense_longitude                                                 NaN
# gis_id                                                ADULT_ARRESTS_5
# creator                                                           NaN
# created                                                           NaN
# editor                                                           JLAY
# edited                                         2023/09/27 21:18:52+00
# globalid                       {2DCB5E7E-311F-48B8-A36B-BF1D6C2890F5}
# objectid                                                          5.0
# date                                        2013-12-09 05:00:00+00:00
# month_year                                        2013-12-01 00:00:00

# %%
sns.lineplot(
    data=arrest_data[(arrest_data.offense_district == "3D")]
    .groupby(["month_year"])
    .ccn.count()
    .reset_index(),
    x="month_year",
    y="ccn",
)
# Out:
# <Axes: xlabel='month_year', ylabel='ccn'>

# %%
arrest_data
# Out:
#                 type       year                   date_  hour  \
# 0       Adult Arrest 2013-01-01  2013/11/14 05:00:00+00     6
# 1       Adult Arrest 2013-01-01  2013/11/20 05:00:00+00    15
# 2       Adult Arrest 2013-01-01  2013/12/03 05:00:00+00     0
# 3       Adult Arrest 2013-01-01  2013/12/05 05:00:00+00    21
# 4       Adult Arrest 2013-01-01  2013/12/09 05:00:00+00    23
# ...              ...        ...                     ...   ...
# 275411         Adult 2023-01-01              2023-12-31    23
# 275412         Adult 2023-01-01              2023-12-31    23
# 275413         Adult 2023-01-01              2023-12-31    23
# 275414         Adult 2023-01-01              2023-12-31    23
# 275415         Adult 2023-01-01              2023-12-31    23
#
#                                                       ccn  \
# 0       45bb932cb42f1bba872a8dfcfb2428a10d6fe0598a63f2...
# 1       d558ea651a7b32e88571a453ccdf39376b2ec9dfb11f3c...
# 2       85451f87475b042563ddebc20b89b7258f07bca9b55b77...
# 3       3498c726acd19b8fc48c50a86c4e21e5823c41722cb779...
# 4       88e342ab716f545b67c467914d6999d514ec6ea34d5c2e...
# ...                                                   ...
# 275411           fb9b703ecf9568a3229c44c6040912c4f86bbddb
# 275412           bf2cb2ac8052147bf1e3c207b9d61da28a9a2810
# 275413           68f2a1a713424941ab9f6eadb6c897e07de01d0b
# 275414           b364f729796fceaac1c0d25c5710204a9214f554
# 275415           ae5271291130385bbd42e2259ccbb00f254600ee
#
#                                             arrest_number  age defendant_psa  \
# 0       1057043c3187ebc5c85920edbb441300e1446d3764e70f...   37  Out of State
# 1       ad3f22534b1e2c409d66328bb4ac3904e9bacc768c6091...   39           602
# 2       a723e9f1d0b44a6e0cef81994b8e7d3d3da55270e6f871...   40  Out of State
# 3       1a94d5a92f8538d3252aa65690ab70fac1a67646eb22ee...   65           502
# 4       5a0e432aaa38e011a7b8aa29de617d4e635acab29b3db5...   31           702
# ...                                                   ...  ...           ...
# 275411           6ef2c06ff6a1dd03c535cb5a8dda934ebd76ae3e   29         402.0
# 275412           041055c6b46ec967b6f3af3d3bd9cc1f3d339d5a   29         507.0
# 275413           2eaa6f4b9ad9709d7fe0c7ac72c5111abf7630f9   27         708.0
# 275414           61b2932a545960b104209222427b9e20a624597e   53           NaN
# 275415           67884b299b3b168a870fa1c443bd40e7da33b34e   39         606.0
#
#        defendant_district   race     ethnicity     sex  \
# 0            Out of State  WHITE  NOT HISPANIC    MALE
# 1                      6D  BLACK           NaN    MALE
# 2            Out of State  BLACK           NaN    MALE
# 3                      5D  BLACK           NaN    MALE
# 4                      7D  BLACK  NOT HISPANIC    MALE
# ...                   ...    ...           ...     ...
# 275411                 4D  BLACK  NOT HISPANIC    MALE
# 275412                 5D  BLACK  NOT HISPANIC    MALE
# 275413                 7D  BLACK  NOT HISPANIC  FEMALE
# 275414                NaN  BLACK       UNKNOWN    MALE
# 275415                 6D  BLACK       UNKNOWN    MALE
#
#                                  category  \
# 0                               Sex Abuse
# 1                                Homicide
# 2                            Prostitution
# 3                               Narcotics
# 4                      Traffic Violations
# ...                                   ...
# 275411        Release Violations/Fugitive
# 275412                     Simple Assault
# 275413                  Weapon Violations
# 275414  Driving/Boating While Intoxicated
# 275415                  Weapon Violations
#
#                                               description  arrest_psa  \
# 0                    Second Degree Sex Abuse- Incompetent       102.0
# 1                                                Murder I       602.0
# 2                                  Solicting Prostitution       103.0
# 3                                        Ucsa Pwid Heroin       102.0
# 4                                               No Permit       204.0
# ...                                                   ...         ...
# 275411                              Fugitive From Justice       405.0
# 275412                                     Simple Assault       507.0
# 275413        Carry Pistol W/o Lic -outside Home/business       604.0
# 275414    Driving Under The Influence Of Alcohol Or Drugs       106.0
# 275415  Carrying a Pistol Without a License (Outside H...       602.0
#
#        arrest_district  arrest_blockx  arrest_blocky  offense_blocky  \
# 0                   1D       398600.0       136300.0             NaN
# 1                   6D       405900.0       137300.0             NaN
# 2                   1D       399200.0       137200.0             NaN
# 3                   1D       398400.0       136900.0             NaN
# 4                   2D            NaN            NaN             NaN
# ...                ...            ...            ...             ...
# 275411              4D       398600.0       140200.0        140200.0
# 275412              5D       402300.0       137500.0        137500.0
# 275413              6D       406200.0       135000.0        135000.0
# 275414              1D       399300.0       133800.0        133800.0
# 275415              6D       405200.0       137000.0        137000.0
#
#         offense_blockx offense_psa offense_district  arrest_latitude  \
# 0                  NaN         NaN              NaN              NaN
# 1                  NaN         602               6D              NaN
# 2                  NaN         NaN              NaN              NaN
# 3                  NaN         NaN              NaN              NaN
# 4                  NaN         NaN              NaN              NaN
# ...                ...         ...              ...              ...
# 275411        398600.0         405               4D           38.930
# 275412        402300.0         507               5D           38.905
# 275413        406200.0         604               6D           38.883
# 275414        399300.0         106               1D           38.872
# 275415        405200.0         602               6D           38.901
#
#         arrest_longitude  offense_latitude  offense_longitude  \
# 0                    NaN               NaN                NaN
# 1                    NaN               NaN                NaN
# 2                    NaN               NaN                NaN
# 3                    NaN               NaN                NaN
# 4                    NaN               NaN                NaN
# ...                  ...               ...                ...
# 275411           -77.016            38.930            -77.016
# 275412           -76.974            38.905            -76.974
# 275413           -76.929            38.883            -76.929
# 275414           -77.009            38.872            -77.009
# 275415           -76.940            38.901            -76.940
#
#                  gis_id creator created editor                  edited  \
# 0       ADULT_ARRESTS_1     NaN     NaN   JLAY  2023/09/27 21:18:52+00
# 1       ADULT_ARRESTS_2     NaN     NaN   JLAY  2023/09/27 21:18:52+00
# 2       ADULT_ARRESTS_3     NaN     NaN   JLAY  2023/09/27 21:18:52+00
# 3       ADULT_ARRESTS_4     NaN     NaN   JLAY  2023/09/27 21:18:52+00
# 4       ADULT_ARRESTS_5     NaN     NaN   JLAY  2023/09/27 21:18:52+00
# ...                 ...     ...     ...    ...                     ...
# 275411              NaN     NaN     NaN    NaN                     NaN
# 275412              NaN     NaN     NaN    NaN                     NaN
# 275413              NaN     NaN     NaN    NaN                     NaN
# 275414              NaN     NaN     NaN    NaN                     NaN
# 275415              NaN     NaN     NaN    NaN                     NaN
#
#                                       globalid  objectid  \
# 0       {80CA3650-32C9-42C6-8412-9250D0E433BF}       1.0
# 1       {F1B2E42E-38B5-49D6-8A60-BF8CF0690A12}       2.0
# 2       {7F8BA37F-51F5-437F-A8F4-4B755385797B}       3.0
# 3       {70B94138-C9F4-4CFF-9A72-12B071F3A78C}       4.0
# 4       {2DCB5E7E-311F-48B8-A36B-BF1D6C2890F5}       5.0
# ...                                        ...       ...
# 275411                                     NaN       NaN
# 275412                                     NaN       NaN
# 275413                                     NaN       NaN
# 275414                                     NaN       NaN
# 275415                                     NaN       NaN
#
#                              date month_year
# 0       2013-11-14 05:00:00+00:00 2013-11-01
# 1       2013-11-20 05:00:00+00:00 2013-11-01
# 2       2013-12-03 05:00:00+00:00 2013-12-01
# 3       2013-12-05 05:00:00+00:00 2013-12-01
# 4       2013-12-09 05:00:00+00:00 2013-12-01
# ...                           ...        ...
# 275411        2023-12-31 00:00:00 2023-12-01
# 275412        2023-12-31 00:00:00 2023-12-01
# 275413        2023-12-31 00:00:00 2023-12-01
# 275414        2023-12-31 00:00:00 2023-12-01
# 275415        2023-12-31 00:00:00 2023-12-01
#
# [275416 rows x 35 columns]

# %%
arrest_data[
    (arrest_data.offense_district == "3D")
    & arrest_data["year"].isin(["2019-01-01", "2023-01-01"])
].groupby(["year", "category"]).ccn.count().reset_index().to_clipboard()

# %%
Sept 2023: 3328
Sept 2020: 3798
Sept 2019: 3795
# Out:
#   Cell In[53], line 1
#     Sept 2023: 3328
#          ^
# SyntaxError: invalid syntax

# %%
arrest_data.defendant_district.value_counts()
# Out:
# defendant_district
# 7D              48070
# 6D              44456
# Out of State    39938
# 5D              29566
# 4D              23435
# 1D              17685
# 3D              14757
# 2D               4657
# UNK              2458
# Name: count, dtype: int64

# %%
arrest_data["defendant_out_of_state"] = (
    arrest_data.defendant_district == "Out of State"
) | (arrest_data.defendant_district.isna())

# %%
arrest_data[(arrest_data.offense_district == "3D")].groupby(
    ["year.1", "defendant_out_of_state"]
).ccn.count()
# Out:
# year.1  defendant_out_of_state
# 2013    False                     3132
#         True                      1319
# 2014    False                     2936
#         True                      1337
# 2015    False                     2173
#         True                      1143
# 2016    False                     2186
#         True                      1275
# 2017    False                     1910
#         True                      1192
# 2018    False                     2016
#         True                      1449
# 2019    False                     1763
#         True                      1298
# 2020    False                     1241
#         True                       831
# 2021    False                     1040
#         True                       689
# 2022    False                     1009
#         True                       790
# Name: ccn, dtype: int64

# %% [markdown]
# ## Juvenile Arrests

# %%
juvenile_arrests = pd.read_csv("../data/raw/Juvenile_Arrests.csv")

# %%
juvenile_arrests.columns = [c.lower() for c in juvenile_arrests.columns]

# %%
juvenile_arrests["year"] = [d[:4] for d in juvenile_arrests.arrest_date.values]
juvenile_arrests["month_year"] = [
    d[:7].replace("/", "-") for d in juvenile_arrests.arrest_date.values
]

# %%
juvenile_arrests.month_year.value_counts().sort_index()
# Out:
# month_year
# 2011-01    271
# 2011-02    261
# 2011-03    341
# 2011-04    300
# 2011-05    305
# 2011-06    281
# 2011-07    255
# 2011-08    304
# 2011-09    334
# 2011-10    264
# 2011-11    304
# 2011-12    279
# 2012-01    271
# 2012-02    253
# 2012-03    265
# 2012-04    243
# 2012-05    313
# 2012-06    256
# 2012-07    235
# 2012-08    248
# 2012-09    207
# 2012-10    237
# 2012-11    236
# 2012-12    258
# 2013-01    250
# 2013-02    241
# 2013-03    307
# 2013-04    285
# 2013-05    293
# 2013-06    266
# 2013-07    251
# 2013-08    241
# 2013-09    283
# 2013-10    283
# 2013-11    248
# 2013-12    225
# 2014-01    243
# 2014-02    226
# 2014-03    262
# 2014-04    244
# 2014-05    270
# 2014-06    259
# 2014-07    268
# 2014-08    222
# 2014-09    238
# 2014-10    276
# 2014-11    237
# 2014-12    237
# 2015-01    240
# 2015-02    220
# 2015-03    256
# 2015-04    252
# 2015-05    290
# 2015-06    268
# 2015-07    269
# 2015-08    273
# 2015-09    286
# 2015-10    277
# 2015-11    224
# 2015-12    286
# 2016-01    262
# 2016-02    298
# 2016-03    269
# 2016-04    323
# 2016-05    299
# 2016-06    247
# 2016-07    228
# 2016-08    286
# 2016-09    312
# 2016-10    314
# 2016-11    225
# 2016-12    215
# 2017-01    260
# 2017-02    266
# 2017-03    239
# 2017-04    268
# 2017-05    265
# 2017-06    265
# 2017-07    235
# 2017-08    255
# 2017-09    206
# 2017-10    270
# 2017-11    233
# 2017-12    221
# 2018-01    212
# 2018-02    246
# 2018-03    224
# 2018-04    230
# 2018-05    280
# 2018-06    223
# 2018-07    242
# 2018-08    162
# 2018-09    241
# 2018-10    244
# 2018-11    235
# 2018-12    181
# 2019-01    225
# 2019-02    221
# 2019-03    236
# 2019-04    223
# 2019-05    208
# 2019-06    212
# 2019-07    268
# 2019-08    182
# 2019-09    261
# 2019-10    276
# 2019-11    234
# 2019-12    213
# 2020-01    215
# 2020-02    194
# 2020-03    115
# 2020-04    123
# 2020-05     99
# 2020-06     95
# 2020-07    152
# 2020-08    112
# 2020-09     86
# 2020-10    119
# 2020-11    115
# 2020-12    109
# 2021-01    129
# 2021-02     97
# 2021-03    116
# 2021-04    111
# 2021-05     94
# 2021-06    113
# 2021-07    147
# 2021-08    115
# 2021-09    109
# 2021-10     85
# 2021-11    144
# 2021-12    141
# 2022-01    144
# 2022-02    158
# 2022-03    142
# 2022-04    171
# 2022-05    103
# 2022-06    129
# 2022-07    117
# 2022-08    147
# 2022-09    135
# 2022-10    147
# 2022-11    161
# 2022-12    128
# 2023-01    145
# 2023-02    131
# 2023-03    145
# 2023-04    173
# 2023-05    188
# 2023-06    210
# Name: count, dtype: int64

# %%
msr = monthly_summary_rates[
    (monthly_summary_rates.Month > "2017-12-01")
    & (monthly_summary_rates.variable != "Incidents per Officer per Month")
]

# %%
msr.to_clipboard()

# %%
incident_data[incident_data.year > "2023-12-31"].month_year.value_counts()
# Out:
# month_year
# 2024-01-01    2357
# 2024-02-01    2121
# 2024-03-01    1009
# Name: count, dtype: int64

# %%
stop_data.stop_reason_nonticket.value_counts()
# Out:
# stop_reason_nonticket
# Call for service                                                                                                                 38315
# Traffic violation                                                                                                                11551
# Warrant/court order                                                                                                               9507
# Individual<U+0092>s actions                                                                                                       6794
# BOLO/Lookout                                                                                                                      6502
#                                                                                                                                  ...
# Response to crash; Individual<U+0092>s actions; Individual<U+0092>s characteristics                                                  1
# Demeanor during a field contact; Prior knowledge; Warrant/court order                                                                1
# Information obtained from law enforcement sources; Prior knowledge; Suspicion of criminal activity (self-initiated)                  1
# BOLO/Lookout; Demeanor during a field contact; Individual<U+0092>s actions; Information obtained from witnesses or informants        1
#  BOLO/Lookout, Information obtained from witnesses or informants, Prior knowledge                                                    1
# Name: count, Length: 2679, dtype: int64
