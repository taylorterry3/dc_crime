# %%
import pandas as pd
import seaborn as sns

# %%
pd.options.display.max_rows = 9999
pd.options.display.max_columns = 999

# %%
all_311 = pd.read_csv("../data/raw/311_City_Service_Requests_in_2023.csv.gz")
# Out:
# /var/folders/tx/fmb4v8gn6mj5c6shgzfqgkjm0000gq/T/ipykernel_80579/1366535624.py:1: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_311 = pd.read_csv("../data/raw/311_City_Service_Requests_in_2023.csv.gz")

# %%
all_311[all_311.SERVICECODEDESCRIPTION == "Traffic Safety Input"].sample(5).T
# Out:
#                                                             346996  \
# X                                                       -77.017228
# Y                                                        38.914452
# OBJECTID                                                  11182963
# SERVICECODE                                               SPSTDAMA
# SERVICECODEDESCRIPTION                        Traffic Safety Input
# SERVICETYPECODEDESCRIPTION            Department of Transportation
# ORGANIZATIONACRONYM                                           DDOT
# SERVICECALLCOUNT                                                 1
# ADDDATE                                     2023/10/15 22:19:24+00
# RESOLUTIONDATE                              2023/10/15 22:28:11+00
# SERVICEDUEDATE                              2023/10/16 22:19:23+00
# SERVICEORDERDATE                            2023/10/15 22:19:24+00
# INSPECTIONFLAG                                                 NaN
# ...
