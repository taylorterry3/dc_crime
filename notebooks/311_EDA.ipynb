# %%
import pandas as pd
import seaborn as sns

pd.options.display.max_rows = 9999
pd.options.display.max_columns = 999

# %%
all_requests = pd.read_csv("../data/clean/311_data.csv.gz")
# Out:
# /var/folders/tx/fmb4v8gn6mj5c6shgzfqgkjm0000gq/T/ipykernel_63426/3136150350.py:1: DtypeWarning: Columns (13,28,29,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_requests = pd.read_csv("../data/clean/311_data.csv.gz")

# %%
all_requests.columns = all_requests.columns.str.lower()

# %%
all_requests.describe()
# Out:
#                   x             y      objectid  servicecallcount  \
# count  2.231219e+06  2.231219e+06  2.231219e+06         2231219.0
# mean   1.231213e+05  4.266955e+04  1.024176e+07               1.0
# std    1.844052e+05  6.384032e+04  8.668056e+05               0.0
# min   -7.711828e+01  3.879325e+01  7.689962e+06               1.0
# 25%   -7.702444e+01  3.890040e+01  9.473408e+06               1.0
# 50%   -7.698996e+01  3.893040e+01  1.018302e+07               1.0
# 75%    3.966161e+05  1.350877e+05  1.108413e+07               1.0
# max    4.078484e+05  1.475118e+05  1.181617e+07               1.0
#
#        inspectionflag  inspectorname  status_code        xcoord        ycoord  \
# count   263380.000000            0.0          0.0  2.231219e+06  2.231219e+06
# mean         0.107692            NaN          NaN  3.987077e+05  1.379889e+05
# std          0.309992            NaN          NaN  1.303423e+04  5.684275e+03
# ...

# %%
all_requests.columns
# Out:
# Index(['x', 'y', 'objectid', 'servicecode', 'servicecodedescription',
#        'servicetypecodedescription', 'organizationacronym', 'servicecallcount',
#        'adddate', 'resolutiondate', 'serviceduedate', 'serviceorderdate',
#        'inspectionflag', 'inspectiondate', 'inspectorname',
#        'serviceorderstatus', 'status_code', 'servicerequestid', 'priority',
#        'streetaddress', 'xcoord', 'ycoord', 'latitude', 'longitude', 'city',
#        'state', 'zipcode', 'maraddressrepositoryid', 'ward', 'details',
#        'gis_id', 'globalid', 'creator', 'created', 'editor', 'edited',
#        'gdb_from_date', 'gdb_to_date', 'gdb_archive_oid'],
#       dtype='object')

# %%
all_requests.servicecodedescription.value_counts().head(10)
# Out:
# servicecodedescription
# Bulk Collection                         388478
# Parking Enforcement                     273926
# Trash Collection - Missed                99115
# Illegal Dumping                          84473
# Scheduled Yard Waste                     79614
# Parking Meter Repair                     79148
# Rodent Inspection and Treatment          74636
# Roadway Signs                            70618
# Sanitation Enforcement                   67941
# Residential Parking Permit Violation     67572
# Name: count, dtype: int64

# %%
all_requests["adddate_dt"].dt.year.value_counts()*0.037
# Out:
# adddate_dt
# 2023    15734.028
# 2022    14269.272
# 2024    14256.063
# 2019    13639.162
# 2021    13348.934
# 2020    11307.644
# Name: count, dtype: float64

# %%
all_requests[(all_requests.servicecodedescription == "Roadway Striping / Markings") & all_requests.streetaddress.str.contains("14TH STREET NW")]
# Out:
#                      x              y  objectid servicecode  \
# 12978       -77.033428      38.955688   9605167    MARKINST
# 20578       -77.032363      38.922012   9613042    MARKINST
# 34730       -77.033033      38.928177   9627436    MARKINST
# 50459       -77.032728      38.944004   9647763    MARKINST
# 88486       -77.032729      38.942405   9694406    MARKINST
# 88824       -77.032729      38.942405   9694744    MARKINST
# 94242       -77.033098      38.965573   9700498    MARKINST
# 104266      -77.032040      38.922694   9710907    MARKINST
# 107067      -77.032729      38.947203   9713708    MARKINST
# 107122      -77.032728      38.944004   9713763    MARKINST
# 112108      -77.032728      38.944004   9719053    MARKINST
# 120013      -77.032085      38.920762   9727598    MARKINST
# 124477      -77.032363      38.922012   9732474    MARKINST
# 150843      -77.032425      38.926567   9759979    MARKINST
# 193944      -77.032146      38.923772   9803082    MARKINST
# ...

# %%
all_requests["adddate_dt"] = pd.to_datetime(all_requests.adddate)

# %%
all_requests["resolutiondate_dt"] = pd.to_datetime(all_requests.resolutiondate)

# %%
all_requests[(all_requests.servicecodedescription == "Illegal Dumping")].apply(lambda x: x["resolutiondate_dt"]- x["adddate_dt"], axis=1).describe()
# Out:
# count                         83114
# mean     10 days 16:41:38.640734413
# std      11 days 09:55:42.416191591
# min                 0 days 00:00:01
# 25%          2 days 23:42:47.500000
# 50%          6 days 23:32:13.500000
# 75%         14 days 17:56:51.500000
# max               308 days 18:52:23
# dtype: object
